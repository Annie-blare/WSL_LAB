# %% [markdown]
# <a href="https://colab.research.google.com/github/Annie-blare/WSL_LAB/blob/main/Copy_of_RRB_AgricultureLoan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

def individual_analysis(file_path, district_name, variable1, variable2, user_perturbations):
    # Load the dataset
    data = pd.read_csv(file_path)

    # Selecting the specified variables
    X = data[[variable1]]
    y = data[variable2]

    # Performing linear regression
    model = LinearRegression()
    model.fit(X, y)
    m = model.coef_[0]  # Slope
    c = model.intercept_  # Intercept

    # Extracting variable1 for the specified district
    district_variable1 = data.loc[data['District'] == district_name, variable1].iloc[0]

    # User provided perturbations in percentages
    perturbations_corrected = [p / 100.0 for p in user_perturbations]

    # Calculating variable2(old) for the specified district
    variable2_old = data.loc[data['District'] == district_name, variable2].iloc[0]

    # Min-max normalization for variable2(old)
    variable2_min = y.min()
    variable2_max = y.max()
    normalized_variable2_old = (variable2_old - variable2_min) / (variable2_max - variable2_min)

    # Applying corrected perturbations and calculating new values
    results_corrected = []
    for p in perturbations_corrected:
        perturbed_variable1 = district_variable1 * (1 + p)
        variable2_new = m * perturbed_variable1 + c
        normalized_variable2_new = (variable2_new - variable2_min) / (variable2_max - variable2_min)
        change_in_variable2 = variable2_new - variable2_old
        impact = normalized_variable2_new - normalized_variable2_old

        results_corrected.append({
            'Perturbation': f'P{user_perturbations.index(p*100)+1}',
            'Magnitude (%)': p*100,
            f'{variable2}_old': variable2_old,
            f'Normalized_{variable2}_old': normalized_variable2_old,
            f'{variable2}_new': variable2_new,
            f'Normalized_{variable2}_new': normalized_variable2_new,
            f'Change_in_{variable2}': change_in_variable2,
            'Impact': impact
        })

    results_df_corrected = pd.DataFrame(results_corrected)
    print(results_df_corrected)

# Example Usage:
file_path = '/content/Agriculture_KAG_2016_17.csv'
district_name = 'BENGALURU'
variable1 = 'TotalNPK'
variable2 = 'RRB_AgricultureLoan'
user_perturbations = [10, -10, -20, 20]
individual_analysis(file_path, district_name, variable1, variable2, user_perturbations)
# Out:
#   Perturbation  Magnitude (%)  RRB_AgricultureLoan_old  \
# 0           P1           10.0                  3450.06
# 1           P2          -10.0                  3450.06
# 2           P3          -20.0                  3450.06
# 3           P4           20.0                  3450.06
#
#    Normalized_RRB_AgricultureLoan_old  RRB_AgricultureLoan_new  \
# 0                                 0.0             39662.773254
# 1                                 0.0             35765.704096
# 2                                 0.0             33817.169517
# 3                                 0.0             41611.307833
#
#    Normalized_RRB_AgricultureLoan_new  Change_in_RRB_AgricultureLoan    Impact
# 0                            0.218056                   36212.713254  0.218056
# 1                            0.194590                   32315.644096  0.194590
# 2                            0.182856                   30367.109517  0.182856
# 3                            0.229789                   38161.247833  0.229789

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

def district_analysis(file_path, variable1, variable2, user_perturbations):
    # Load the dataset
    data = pd.read_csv(file_path)

    # Performing linear regression on the entire dataset
    X = data[[variable1]]
    y = data[variable2]
    model = LinearRegression()
    model.fit(X, y)
    m = model.coef_[0]  # Slope
    c = model.intercept_  # Intercept

    # User provided perturbations in percentages
    perturbations_corrected = [p / 100.0 for p in user_perturbations]

    # Min-max normalization parameters for variable2
    variable2_min = y.min()
    variable2_max = y.max()

    # Loop through each unique district in the dataset
    for district in data['District'].unique():
        district_variable1 = data.loc[data['District'] == district, variable1].iloc[0]
        variable2_old = data.loc[data['District'] == district, variable2].iloc[0]
        normalized_variable2_old = (variable2_old - variable2_min) / (variable2_max - variable2_min)

        district_results = []

        # Applying perturbations and calculating new values for each perturbation
        for p in perturbations_corrected:
            perturbed_variable1 = district_variable1 * (1 + p)
            variable2_new = m * perturbed_variable1 + c
            normalized_variable2_new = (variable2_new - variable2_min) / (variable2_max - variable2_min)
            change_in_variable2 = variable2_new - variable2_old
            impact = normalized_variable2_new - normalized_variable2_old

            district_results.append({
                'Perturbation (%)': p * 100,
                f'{variable2}_old': variable2_old,
                f'Normalized_{variable2}_old': normalized_variable2_old,
                f'{variable2}_new': variable2_new,
                f'Normalized_{variable2}_new': normalized_variable2_new,
                f'Change_in_{variable2}': change_in_variable2,
                'Impact': impact
            })

        # Convert the district results into a DataFrame and print it
        district_df = pd.DataFrame(district_results)
        print(f"Results for {district}:")
        print(district_df)
        print("\n")  # Add a newline for better readability between districts

# Example Usage:
file_path = '/content/Agriculture_KAG_2016_17.csv'
variable1 = 'TotalNPK'
variable2 = 'RRB_AgricultureLoan'
user_perturbations = [10, -10, -20, 20]
district_analysis(file_path, variable1, variable2, user_perturbations)
# Out:
# Results for BENGALURU:
#    Perturbation (%)  RRB_AgricultureLoan_old  \
# 0              10.0                  3450.06
# 1             -10.0                  3450.06
# 2             -20.0                  3450.06
# 3              20.0                  3450.06
#
#    Normalized_RRB_AgricultureLoan_old  RRB_AgricultureLoan_new  \
# 0                                 0.0             39662.773254
# 1                                 0.0             35765.704096
# 2                                 0.0             33817.169517
# 3                                 0.0             41611.307833
#
#    Normalized_RRB_AgricultureLoan_new  Change_in_RRB_AgricultureLoan    Impact
# 0                            0.218056                   36212.713254  0.218056
# 1                            0.194590                   32315.644096  0.194590
# 2                            0.182856                   30367.109517  0.182856
# 3                            0.229789                   38161.247833  0.229789
#
#
# Results for BENGALURU(R):
#    Perturbation (%)  RRB_AgricultureLoan_old  \
# 0              10.0                 10539.94
# 1             -10.0                 10539.94
# 2             -20.0                 10539.94
# 3              20.0                 10539.94
#
#    Normalized_RRB_AgricultureLoan_old  RRB_AgricultureLoan_new  \
# 0                            0.042692             35937.820471
# 1                            0.042692             32718.015456
# 2                            0.042692             31108.112948
# 3                            0.042692             37547.722979
#
#    Normalized_RRB_AgricultureLoan_new  Change_in_RRB_AgricultureLoan    Impact
# 0                            0.195626                   25397.880471  0.152934
# 1                            0.176238                   22178.075456  0.133546
# 2                            0.166544                   20568.172948  0.123852
# 3                            0.205320                   27007.782979  0.162628
#
#
# Results for RAMANAGARA:
#    Perturbation (%)  RRB_AgricultureLoan_old  \
# 0              10.0                  9921.94
# 1             -10.0                  9921.94
# 2             -20.0                  9921.94
# 3              20.0                  9921.94
#
#    Normalized_RRB_AgricultureLoan_old  RRB_AgricultureLoan_new  \
# 0                            0.038971             25099.504388
# 1                            0.038971             23850.302297
# 2                            0.038971             23225.701252
# 3                            0.038971             25724.105434
#
#    Normalized_RRB_AgricultureLoan_new  Change_in_RRB_AgricultureLoan    Impact
# 0                            0.130363                   15177.564388  0.091392
# 1                            0.122841                   13928.362297  0.083870
# 2                            0.119080                   13303.761252  0.080109
# 3                            0.134124                   15802.165434  0.095153
#
#
# Results for CHITRADURGA:
#    Perturbation (%)  RRB_AgricultureLoan_old  \
# 0              10.0                105785.02
# 1             -10.0                105785.02
# 2             -20.0                105785.02
# 3              20.0                105785.02
#
#    Normalized_RRB_AgricultureLoan_old  RRB_AgricultureLoan_new  \
# 0                            0.616213             51224.747159
# 1                            0.616213             45225.500928
# 2                            0.616213             42225.877812
# 3                            0.616213             54224.370275
#
#    Normalized_RRB_AgricultureLoan_new  Change_in_RRB_AgricultureLoan    Impact
# 0                            0.287677                  -54560.272841 -0.328536
# 1                            0.251552                  -60559.519072 -0.364661
# 2                            0.233490                  -63559.142188 -0.382723
# 3                            0.305739                  -51560.649725 -0.310474
#
#
# Results for DAVANAGERE:
#    Perturbation (%)  RRB_AgricultureLoan_old  \
# 0              10.0                 80725.12
# 1             -10.0                 80725.12
# 2             -20.0                 80725.12
# 3              20.0                 80725.12
#
#    Normalized_RRB_AgricultureLoan_old  RRB_AgricultureLoan_new  \
# 0                            0.465314            109852.984491
# 1                            0.465314             93194.058745
# 2                            0.465314             84864.595872
# 3                            0.465314            118182.447364
#
#    Normalized_RRB_AgricultureLoan_new  Change_in_RRB_AgricultureLoan    Impact
# 0                            0.640708                   29127.864491  0.175394
# 1                            0.540396                   12468.938745  0.075082
# 2                            0.490240                    4139.475872  0.024926
# 3                            0.690865                   37457.327364  0.225550
#
#
# Results for KOLAR:
#    Perturbation (%)  RRB_AgricultureLoan_old  \
# 0              10.0                 70194.91
# 1             -10.0                 70194.91
# 2             -20.0                 70194.91
# 3              20.0                 70194.91
#
#    Normalized_RRB_AgricultureLoan_old  RRB_AgricultureLoan_new  \
# 0                            0.401906             38632.917140
# 1                            0.401906             34923.094549
# 2                            0.401906             33068.183253
# 3                            0.401906             40487.828436
#
#    Normalized_RRB_AgricultureLoan_new  Change_in_RRB_AgricultureLoan    Impact
# 0                            0.211855                  -31561.992860 -0.190052
# 1                            0.189516                  -35271.815451 -0.212390
# 2                            0.178346                  -37126.726747 -0.223560
# 3                            0.223024                  -29707.081564 -0.178882
#
#
# Results for CHIKKABALLAPURA:
#    Perturbation (%)  RRB_AgricultureLoan_old  \
# 0              10.0                 48782.34
# 1             -10.0                 48782.34
# 2             -20.0                 48782.34
# 3              20.0                 48782.34
#
#    Normalized_RRB_AgricultureLoan_old  RRB_AgricultureLoan_new  \
# 0                             0.27297             44303.562366
# 1                             0.27297             39562.713370
# 2                             0.27297             37192.288872
# 3                             0.27297             46673.986864
#
#    Normalized_RRB_AgricultureLoan_new  Change_in_RRB_AgricultureLoan    Impact
# 0                            0.246001                   -4478.777634 -0.026969
# 1                            0.217453                   -9219.626630 -0.055516
# 2                            0.203180                  -11590.051128 -0.069790
# 3                            0.260274                   -2108.353136 -0.012696
#
#
# Results for SHIVAMOGGA:
#    Perturbation (%)  RRB_AgricultureLoan_old  \
# 0              10.0                 69036.55
# 1             -10.0                 69036.55
# 2             -20.0                 69036.55
# 3              20.0                 69036.55
#
#    Normalized_RRB_AgricultureLoan_old  RRB_AgricultureLoan_new  \
# 0                            0.394931             70281.682835
# 1                            0.394931             60817.539208
# 2                            0.394931             56085.467395
# 3                            0.394931             75013.754649
#
#    Normalized_RRB_AgricultureLoan_new  Change_in_RRB_AgricultureLoan    Impact
# 0                            0.402429                    1245.132835  0.007498
# 1                            0.345440                   -8219.010792 -0.049491
# 2                            0.316946                  -12951.082605 -0.077985
# 3                            0.430923                    5977.204649  0.035992
#
#
# Results for TUMAKURU:
#    Perturbation (%)  RRB_AgricultureLoan_old  \
# 0              10.0                104566.89
# 1             -10.0                104566.89
# 2             -20.0                104566.89
# 3              20.0                104566.89
#
#    Normalized_RRB_AgricultureLoan_old  RRB_AgricultureLoan_new  \
# 0                            0.608878             53306.527732
# 1                            0.608878             46928.775942
# 2                            0.608878             43739.900047
# 3                            0.608878             56495.403627
#
#    Normalized_RRB_AgricultureLoan_new  Change_in_RRB_AgricultureLoan    Impact
# 0                            0.300212                  -51260.362268 -0.308666
# 1                            0.261808                  -57638.114058 -0.347070
# 2                            0.242607                  -60826.989953 -0.366272
# 3                            0.319414                  -48071.486373 -0.289464
#
#
# Results for CHIKKAMAGALURU:
#    Perturbation (%)  RRB_AgricultureLoan_old  \
# 0              10.0                 32999.48
# 1             -10.0                 32999.48
# 2             -20.0                 32999.48
# 3              20.0                 32999.48
#
#    Normalized_RRB_AgricultureLoan_old  RRB_AgricultureLoan_new  \
# 0                            0.177933             80629.897749
# 1                            0.177933             69284.260502
# 2                            0.177933             63611.441878
# 3                            0.177933             86302.716373
#
#    Normalized_RRB_AgricultureLoan_new  Change_in_RRB_AgricultureLoan    Impact
# 0                            0.464741                   47630.417749  0.286808
# 1                            0.396423                   36284.780502  0.218490
# 2                            0.362264                   30611.961878  0.184331
# 3                            0.498900                   53303.236373  0.320967
#
#
# Results for DAKSHINA KANNADA:
#    Perturbation (%)  RRB_AgricultureLoan_old  \
# 0              10.0                  7881.51
# 1             -10.0                  7881.51
# 2             -20.0                  7881.51
# 3              20.0                  7881.51
#
#    Normalized_RRB_AgricultureLoan_old  RRB_AgricultureLoan_new  \
# 0                            0.026684             35320.826317
# 1                            0.026684             32213.202057
# 2                            0.026684             30659.389927
# 3                            0.026684             36874.638447
#
#    Normalized_RRB_AgricultureLoan_new  Change_in_RRB_AgricultureLoan    Impact
# 0                            0.191911                   27439.316317  0.165227
# 1                            0.173198                   24331.692057  0.146514
# 2                            0.163842                   22777.879927  0.137158
# 3                            0.201267                   28993.128447  0.174583
#
#
# Results for UDUPI:
#    Perturbation (%)  RRB_AgricultureLoan_old  \
# 0              10.0                  6859.29
# 1             -10.0                  6859.29
# 2             -20.0                  6859.29
# 3              20.0                  6859.29
#
#    Normalized_RRB_AgricultureLoan_old  RRB_AgricultureLoan_new  \
# 0                            0.020529             23882.067340
# 1                            0.020529             22854.217439
# 2                            0.020529             22340.292489
# 3                            0.020529             24395.992290
#
#    Normalized_RRB_AgricultureLoan_new  Change_in_RRB_AgricultureLoan    Impact
# 0                            0.123032                   17022.777340  0.102503
# 1                            0.116843                   15994.927439  0.096314
# 2                            0.113748                   15481.002489  0.093219
# 3                            0.126127                   17536.702290  0.105598
#
#
# Results for HASSAN:
#    Perturbation (%)  RRB_AgricultureLoan_old  \
# 0              10.0                 57943.86
# 1             -10.0                 57943.86
# 2             -20.0                 57943.86
# 3              20.0                 57943.86
#
#    Normalized_RRB_AgricultureLoan_old  RRB_AgricultureLoan_new  \
# 0                            0.328136             81152.181921
# 1                            0.328136             69711.583915
# 2                            0.328136             63991.284912
# 3                            0.328136             86872.480925
#
#    Normalized_RRB_AgricultureLoan_new  Change_in_RRB_AgricultureLoan    Impact
# 0                            0.467886                   23208.321921  0.139750
# 1                            0.398996                   11767.723915  0.070860
# 2                            0.364551                    6047.424912  0.036415
# 3                            0.502331                   28928.620925  0.174195
#
#
# Results for KODAGU:
#    Perturbation (%)  RRB_AgricultureLoan_old  \
# 0              10.0                  8146.07
# 1             -10.0                  8146.07
# 2             -20.0                  8146.07
# 3              20.0                  8146.07
#
#    Normalized_RRB_AgricultureLoan_old  RRB_AgricultureLoan_new  \
# 0                            0.028277             55880.248502
# 1                            0.028277             49034.547481
# 2                            0.028277             45611.696971
# 3                            0.028277             59303.099012
#
#    Normalized_RRB_AgricultureLoan_new  Change_in_RRB_AgricultureLoan    Impact
# 0                            0.315710                   47734.178502  0.287433
# 1                            0.274488                   40888.477481  0.246211
# 2                            0.253878                   37465.626971  0.225600
# 3                            0.336321                   51157.029012  0.308044
#
#
# Results for MANDYA:
#    Perturbation (%)  RRB_AgricultureLoan_old  \
# 0              10.0                 41282.27
# 1             -10.0                 41282.27
# 2             -20.0                 41282.27
# 3              20.0                 41282.27
#
#    Normalized_RRB_AgricultureLoan_old  RRB_AgricultureLoan_new  \
# 0                            0.227808             73912.845151
# 1                            0.227808             63788.490193
# 2                            0.227808             58726.312715
# 3                            0.227808             78975.022629
#
#    Normalized_RRB_AgricultureLoan_new  Change_in_RRB_AgricultureLoan    Impact
# 0                            0.424294                   32630.575151  0.196486
# 1                            0.363330                   22506.220193  0.135522
# 2                            0.332848                   17444.042715  0.105040
# 3                            0.454776                   37692.752629  0.226968
#
#
# Results for MYSURU:
#    Perturbation (%)  RRB_AgricultureLoan_old  \
# 0              10.0                 71615.05
# 1             -10.0                 71615.05
# 2             -20.0                 71615.05
# 3              20.0                 71615.05
#
#    Normalized_RRB_AgricultureLoan_old  RRB_AgricultureLoan_new  \
# 0                            0.410458             75251.658098
# 1                            0.410458             64883.882605
# 2                            0.410458             59699.994859
# 3                            0.410458             80435.545845
#
#    Normalized_RRB_AgricultureLoan_new  Change_in_RRB_AgricultureLoan    Impact
# 0                            0.432356                    3636.608098  0.021898
# 1                            0.369926                   -6731.167395 -0.040532
# 2                            0.338711                  -11915.055141 -0.071747
# 3                            0.463570                    8820.495845  0.053113
#
#
# Results for CHAMARAJANAGAR:
#    Perturbation (%)  RRB_AgricultureLoan_old  \
# 0              10.0                 17385.06
# 1             -10.0                 17385.06
# 2             -20.0                 17385.06
# 3              20.0                 17385.06
#
#    Normalized_RRB_AgricultureLoan_old  RRB_AgricultureLoan_new  \
# 0                             0.08391             40116.093847
# 1                             0.08391             36136.602763
# 2                             0.08391             34146.857221
# 3                             0.08391             42105.839389
#
#    Normalized_RRB_AgricultureLoan_new  Change_in_RRB_AgricultureLoan    Impact
# 0                            0.220786                   22731.033847  0.136876
# 1                            0.196823                   18751.542763  0.112913
# 2                            0.184842                   16761.797221  0.100932
# 3                            0.232767                   24720.779389  0.148857
#
#
# Results for BELAGAVI:
#    Perturbation (%)  RRB_AgricultureLoan_old  \
# 0              10.0                152455.11
# 1             -10.0                152455.11
# 2             -20.0                152455.11
# 3              20.0                152455.11
#
#    Normalized_RRB_AgricultureLoan_old  RRB_AgricultureLoan_new  \
# 0                            0.897238            183734.126479
# 1                            0.897238            153642.265826
# 2                            0.897238            138596.335499
# 3                            0.897238            198780.056805
#
#    Normalized_RRB_AgricultureLoan_new  Change_in_RRB_AgricultureLoan    Impact
# 0                            1.085586                   31279.016479  0.188348
# 1                            0.904387                    1187.155826  0.007148
# 2                            0.813787                  -13858.774501 -0.083451
# 3                            1.176186                   46324.946805  0.278947
#
#
# Results for VIJAYAPURA:
#    Perturbation (%)  RRB_AgricultureLoan_old  \
# 0              10.0                 120443.2
# 1             -10.0                 120443.2
# 2             -20.0                 120443.2
# 3              20.0                 120443.2
#
#    Normalized_RRB_AgricultureLoan_old  RRB_AgricultureLoan_new  \
# 0                            0.704478             68092.319079
# 1                            0.704478             59026.241590
# 2                            0.704478             54493.202845
# 3                            0.704478             72625.357824
#
#    Normalized_RRB_AgricultureLoan_new  Change_in_RRB_AgricultureLoan    Impact
# 0                            0.389245                  -52350.880921 -0.315232
# 1                            0.334654                  -61416.958410 -0.369824
# 2                            0.307358                  -65949.997155 -0.397120
# 3                            0.416541                  -47817.842176 -0.287937
#
#
# Results for BAGALKOT:
#    Perturbation (%)  RRB_AgricultureLoan_old  \
# 0              10.0                  99845.5
# 1             -10.0                  99845.5
# 2             -20.0                  99845.5
# 3              20.0                  99845.5
#
#    Normalized_RRB_AgricultureLoan_old  RRB_AgricultureLoan_new  \
# 0                            0.580448             96214.747099
# 1                            0.580448             82035.500879
# 2                            0.580448             74945.877769
# 3                            0.580448            103304.370209
#
#    Normalized_RRB_AgricultureLoan_new  Change_in_RRB_AgricultureLoan    Impact
# 0                            0.558585                   -3630.752901 -0.021863
# 1                            0.473205                  -17809.999121 -0.107243
# 2                            0.430514                  -24899.622231 -0.149934
# 3                            0.601276                    3458.870209  0.020828
#
#
# Results for DHARAWAD:
#    Perturbation (%)  RRB_AgricultureLoan_old  \
# 0              10.0                 66491.97
# 1             -10.0                 66491.97
# 2             -20.0                 66491.97
# 3              20.0                 66491.97
#
#    Normalized_RRB_AgricultureLoan_old  RRB_AgricultureLoan_new  \
# 0                            0.379609             52601.260197
# 1                            0.379609             46351.738868
# 2                            0.379609             43226.978203
# 3                            0.379609             55726.020862
#
#    Normalized_RRB_AgricultureLoan_new  Change_in_RRB_AgricultureLoan    Impact
# 0                            0.295965                  -13890.709803 -0.083643
# 1                            0.258334                  -20140.231132 -0.121275
# 2                            0.239518                  -23264.991797 -0.140091
# 3                            0.314781                  -10765.949138 -0.064827
#
#
# Results for GADAG:
#    Perturbation (%)  RRB_AgricultureLoan_old  \
# 0              10.0                 71930.38
# 1             -10.0                 71930.38
# 2             -20.0                 71930.38
# 3              20.0                 71930.38
#
#    Normalized_RRB_AgricultureLoan_old  RRB_AgricultureLoan_new  \
# 0                            0.412356             39635.187822
# 1                            0.412356             35743.134198
# 2                            0.412356             33797.107385
# 3                            0.412356             41581.214635
#
#    Normalized_RRB_AgricultureLoan_new  Change_in_RRB_AgricultureLoan    Impact
# 0                            0.217890                  -32295.192178 -0.194466
# 1                            0.194454                  -36187.245802 -0.217903
# 2                            0.182736                  -38133.272615 -0.229621
# 3                            0.229608                  -30349.165365 -0.182748
#
#
# Results for HAVERI:
#    Perturbation (%)  RRB_AgricultureLoan_old  \
# 0              10.0                 90729.71
# 1             -10.0                 90729.71
# 2             -20.0                 90729.71
# 3              20.0                 90729.71
#
#    Normalized_RRB_AgricultureLoan_old  RRB_AgricultureLoan_new  \
# 0                            0.525557             77998.247573
# 1                            0.525557             67131.092176
# 2                            0.525557             61697.514477
# 3                            0.525557             83431.825272
#
#    Normalized_RRB_AgricultureLoan_new  Change_in_RRB_AgricultureLoan    Impact
# 0                            0.448894                  -12731.462427 -0.076663
# 1                            0.383457                  -23598.617824 -0.142100
# 2                            0.350739                  -29032.195523 -0.174818
# 3                            0.481613                   -7297.884728 -0.043944
#
#
# Results for UTTARA KANNADA:
#    Perturbation (%)  RRB_AgricultureLoan_old  \
# 0              10.0                  7341.08
# 1             -10.0                  7341.08
# 2             -20.0                  7341.08
# 3              20.0                  7341.08
#
#    Normalized_RRB_AgricultureLoan_old  RRB_AgricultureLoan_new  \
# 0                             0.02343             32312.175242
# 1                             0.02343             29751.578450
# 2                             0.02343             28471.280054
# 3                             0.02343             33592.473638
#
#    Normalized_RRB_AgricultureLoan_new  Change_in_RRB_AgricultureLoan    Impact
# 0                            0.173794                   24971.095242  0.150364
# 1                            0.158375                   22410.498450  0.134946
# 2                            0.150666                   21130.200054  0.127236
# 3                            0.181503                   26251.393638  0.158074
#
#
# Results for BALLARI:
#    Perturbation (%)  RRB_AgricultureLoan_old  \
# 0              10.0                169520.79
# 1             -10.0                169520.79
# 2             -20.0                169520.79
# 3              20.0                169520.79
#
#    Normalized_RRB_AgricultureLoan_old  RRB_AgricultureLoan_new  \
# 0                                 1.0            131631.682753
# 1                                 1.0            111012.993687
# 2                                 1.0            100703.649153
# 3                                 1.0            141941.027287
#
#    Normalized_RRB_AgricultureLoan_new  Change_in_RRB_AgricultureLoan    Impact
# 0                            0.771850                  -37889.107247 -0.228150
# 1                            0.647694                  -58507.796313 -0.352306
# 2                            0.585615                  -68817.140847 -0.414385
# 3                            0.833928                  -27579.762713 -0.166072
#
#
# Results for BIDAR:
#    Perturbation (%)  RRB_AgricultureLoan_old  \
# 0              10.0                 30398.27
# 1             -10.0                 30398.27
# 2             -20.0                 30398.27
# 3              20.0                 30398.27
#
#    Normalized_RRB_AgricultureLoan_old  RRB_AgricultureLoan_new  \
# 0                            0.162269             40902.278648
# 1                            0.162269             36779.844873
# 2                            0.162269             34718.627986
# 3                            0.162269             42963.495535
#
#    Normalized_RRB_AgricultureLoan_new  Change_in_RRB_AgricultureLoan    Impact
# 0                            0.225520                   10504.008648  0.063250
# 1                            0.200696                    6381.574873  0.038427
# 2                            0.188285                    4320.357986  0.026015
# 3                            0.237931                   12565.225535  0.075662
#
#
# Results for KALABURAGI:
#    Perturbation (%)  RRB_AgricultureLoan_old  \
# 0              10.0                126750.15
# 1             -10.0                126750.15
# 2             -20.0                126750.15
# 3              20.0                126750.15
#
#    Normalized_RRB_AgricultureLoan_old  RRB_AgricultureLoan_new  \
# 0                            0.742455             67881.750284
# 1                            0.742455             58853.958030
# 2                            0.742455             54340.061903
# 3                            0.742455             72395.646412
#
#    Normalized_RRB_AgricultureLoan_new  Change_in_RRB_AgricultureLoan    Impact
# 0                            0.387977                  -58868.399716 -0.354478
# 1                            0.333616                  -67896.191970 -0.408839
# 2                            0.306436                  -72410.088097 -0.436020
# 3                            0.415158                  -54354.503588 -0.327297
#
#
# Results for YADGIRI:
#    Perturbation (%)  RRB_AgricultureLoan_old  \
# 0              10.0                  39555.9
# 1             -10.0                  39555.9
# 2             -20.0                  39555.9
# 3              20.0                  39555.9
#
#    Normalized_RRB_AgricultureLoan_old  RRB_AgricultureLoan_new  \
# 0                            0.217412            102262.393224
# 1                            0.217412             86983.574981
# 2                            0.217412             79344.165859
# 3                            0.217412            109901.802346
#
#    Normalized_RRB_AgricultureLoan_new  Change_in_RRB_AgricultureLoan    Impact
# 0                            0.595001                   62706.493224  0.377589
# 1                            0.503000                   47427.674981  0.285587
# 2                            0.456999                   39788.265859  0.239586
# 3                            0.641002                   70345.902346  0.423590
#
#
# Results for RAICHUR:
#    Perturbation (%)  RRB_AgricultureLoan_old  \
# 0              10.0                123016.32
# 1             -10.0                123016.32
# 2             -20.0                123016.32
# 3              20.0                123016.32
#
#    Normalized_RRB_AgricultureLoan_old  RRB_AgricultureLoan_new  \
# 0                            0.719972            126028.162077
# 1                            0.719972            106428.294952
# 2                            0.719972             96628.361389
# 3                            0.719972            135828.095640
#
#    Normalized_RRB_AgricultureLoan_new  Change_in_RRB_AgricultureLoan    Impact
# 0                            0.738108                    3011.842077  0.018136
# 1                            0.620087                  -16588.025048 -0.099885
# 2                            0.561076                  -26387.958611 -0.158896
# 3                            0.797118                   12811.775640  0.077147
#
#
# Results for KOPPAL:
#    Perturbation (%)  RRB_AgricultureLoan_old  \
# 0              10.0                 58306.59
# 1             -10.0                 58306.59
# 2             -20.0                 58306.59
# 3              20.0                 58306.59
#
#    Normalized_RRB_AgricultureLoan_old  RRB_AgricultureLoan_new  \
# 0                             0.33032             85861.015099
# 1                             0.33032             73564.265606
# 2                             0.33032             67415.890859
# 3                             0.33032             92009.389845
#
#    Normalized_RRB_AgricultureLoan_new  Change_in_RRB_AgricultureLoan    Impact
# 0                            0.496240                   27554.425099  0.165920
# 1                            0.422195                   15257.675606  0.091875
# 2                            0.385172                    9109.300859  0.054852
# 3                            0.533263                   33702.799845  0.202942

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

def bar_graph_analysis(file_path, variable1, variable2, user_perturbations):
    # Load the dataset
    data = pd.read_csv(file_path)

    # Performing linear regression on the entire dataset
    X = data[[variable1]]
    y = data[variable2]
    model = LinearRegression()
    model.fit(X, y)
    m = model.coef_[0]  # Slope
    c = model.intercept_  # Intercept

    # User provided perturbations in percentages
    perturbations_corrected = [p / 100.0 for p in user_perturbations]

    # Min-max normalization parameters for variable2
    variable2_min = y.min()
    variable2_max = y.max()

    # Loop through each unique district in the dataset
    for district in data['District'].unique():
        district_variable1 = data.loc[data['District'] == district, variable1].iloc[0]
        variable2_old = data.loc[data['District'] == district, variable2].iloc[0]
        normalized_old = (variable2_old - variable2_min) / (variable2_max - variable2_min)

        impacts = []

        for p in perturbations_corrected:
            perturbed_variable1 = district_variable1 * (1 + p)
            variable2_new = m * perturbed_variable1 + c
            normalized_new = (variable2_new - variable2_min) / (variable2_max - variable2_min)
            impact = (normalized_new - normalized_old) * 100  # Impact calculation
            impacts.append(impact)

        # Plotting the impacts of each perturbation
        plt.figure(figsize=(10, 6))
        plt.bar([f'{p*100:+.0f}%' for p in perturbations_corrected], impacts, color='skyblue')
        plt.xlabel('Perturbation (Magnitude in %)')
        plt.ylabel('Impact')
        plt.title(f'Impact of Perturbations on {variable2} for {district}')
        plt.axhline(0, color='gray', linewidth=0.8)
        plt.grid(axis='y', linestyle='--', alpha=0.7)
        plt.show()

# Example Usage:
file_path = '/content/Agriculture_KAG_2016_17.csv'
variable1 = 'TotalNPK'
variable2 = 'RRB_AgricultureLoan'
user_perturbations = [10, -10, -20, 20]
bar_graph_analysis(file_path, variable1, variable2, user_perturbations)

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

def choose_perturbation(file_path, variable1, variable2, user_perturbations):
    # Load the dataset
    data = pd.read_csv(file_path)

    # Performing linear regression on the entire dataset
    X = data[[variable1]]
    y = data[variable2]
    model = LinearRegression()
    model.fit(X, y)
    m = model.coef_[0]  # Slope
    c = model.intercept_  # Intercept

    # User provided perturbations in percentages
    perturbations_corrected = [p / 100.0 for p in user_perturbations]

    # Min-max normalization parameters for variable2
    variable2_min = y.min()
    variable2_max = y.max()

    # Initialize an empty list to store results for each district
    district_results = []

    # Loop through each unique district in the dataset
    for district in data['District'].unique():
        district_variable1 = data.loc[data['District'] == district, variable1].iloc[0]
        variable2_old = data.loc[data['District'] == district, variable2].iloc[0]
        normalized_old = (variable2_old - variable2_min) / (variable2_max - variable2_min)

        impacts = []

        for p in perturbations_corrected:
            perturbed_variable1 = district_variable1 * (1 + p)
            variable2_new = m * perturbed_variable1 + c
            normalized_new = (variable2_new - variable2_min) / (variable2_max - variable2_min)
            impact = (normalized_new - normalized_old) * 100  # Impact calculation
            impacts.append((impact, p))

        # Choose perturbation based on conditions
        chosen_perturbation = None
        if all(impact > 0 for impact, _ in impacts):
            chosen_perturbation = min(impacts, key=lambda x: x[0])[1]
        elif all(impact < 0 for impact, _ in impacts):
            chosen_perturbation = min(impacts, key=lambda x: x[0])[1]
        elif any(impact > 0 for impact, _ in impacts) and any(impact < 0 for impact, _ in impacts):
            chosen_perturbation = min(impacts, key=lambda x: x[0])[1]

        district_results.append({
            'District': district,
            'Perturbation_Choosen': f'P{user_perturbations.index(chosen_perturbation*100)+1}'
        })

    # Convert the results into a DataFrame and display
    results_df = pd.DataFrame(district_results)
    print(results_df)

# Example Usage:
file_path = '/content/Agriculture_KAG_2016_17.csv'
variable1 = 'TotalNPK'
variable2 = 'RRB_AgricultureLoan'
user_perturbations = [10, -10, -20, 20]
choose_perturbation(file_path, variable1, variable2, user_perturbations)
# Out:
#             District Perturbation_Choosen
# 0          BENGALURU                   P3
# 1       BENGALURU(R)                   P3
# 2         RAMANAGARA                   P3
# 3        CHITRADURGA                   P3
# 4         DAVANAGERE                   P3
# 5              KOLAR                   P3
# 6    CHIKKABALLAPURA                   P3
# 7         SHIVAMOGGA                   P3
# 8           TUMAKURU                   P3
# 9     CHIKKAMAGALURU                   P3
# 10  DAKSHINA KANNADA                   P3
# 11             UDUPI                   P3
# 12            HASSAN                   P3
# 13            KODAGU                   P3
# 14            MANDYA                   P3
# 15            MYSURU                   P3
# 16    CHAMARAJANAGAR                   P3
# 17          BELAGAVI                   P3
# 18        VIJAYAPURA                   P3
# 19          BAGALKOT                   P3
# 20          DHARAWAD                   P3
# 21             GADAG                   P3
# 22            HAVERI                   P3
# 23    UTTARA KANNADA                   P3
# 24           BALLARI                   P3
# 25             BIDAR                   P3
# 26        KALABURAGI                   P3
# 27           YADGIRI                   P3
# 28           RAICHUR                   P3
# 29            KOPPAL                   P3
