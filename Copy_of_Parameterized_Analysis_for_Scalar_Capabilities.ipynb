# %% [markdown]
# <a href="https://colab.research.google.com/github/Annie-blare/WSL_LAB/blob/main/Copy_of_Parameterized_Analysis_for_Scalar_Capabilities.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

def individual_analysis(file_path, district_name, variable1, variable2, user_perturbations):
    # Load the dataset
    data = pd.read_csv(file_path)

    # Selecting the specified variables
    X = data[[variable1]]
    y = data[variable2]

    # Performing linear regression
    model = LinearRegression()
    model.fit(X, y)
    m = model.coef_[0]  # Slope
    c = model.intercept_  # Intercept

    # Extracting variable1 for the specified district
    district_variable1 = data.loc[data['District'] == district_name, variable1].iloc[0]

    # User provided perturbations in percentages
    perturbations_corrected = [p / 100.0 for p in user_perturbations]

    # Calculating variable2(old) for the specified district
    variable2_old = data.loc[data['District'] == district_name, variable2].iloc[0]

    # Min-max normalization for variable2(old)
    variable2_min = y.min()
    variable2_max = y.max()
    normalized_variable2_old = (variable2_old - variable2_min) / (variable2_max - variable2_min)

    # Applying corrected perturbations and calculating new values
    results_corrected = []
    for p in perturbations_corrected:
        perturbed_variable1 = district_variable1 * (1 + p)
        variable2_new = m * perturbed_variable1 + c
        normalized_variable2_new = (variable2_new - variable2_min) / (variable2_max - variable2_min)
        change_in_variable2 = variable2_new - variable2_old
        impact = normalized_variable2_new - normalized_variable2_old

        results_corrected.append({
            'Perturbation': f'P{user_perturbations.index(p*100)+1}',
            'Magnitude (%)': p*100,
            f'{variable2}_old': variable2_old,
            f'Normalized_{variable2}_old': normalized_variable2_old,
            f'{variable2}_new': variable2_new,
            f'Normalized_{variable2}_new': normalized_variable2_new,
            f'Change_in_{variable2}': change_in_variable2,
            'Impact': impact
        })

    results_df_corrected = pd.DataFrame(results_corrected)
    print(results_df_corrected)

# Example Usage:
file_path = '/content/Agriculture_KAG_2016_17.csv'
district_name = 'BENGALURU'
variable1 = 'TotalNPK'
variable2 = 'TotalCerealsandMinorMillets_Production'
user_perturbations = [10, -10, -20, 20]
individual_analysis(file_path, district_name, variable1, variable2, user_perturbations)
# Out:
#   Perturbation  Magnitude (%)  TotalCerealsandMinorMillets_Production_old  \
# 0           P1           10.0                                       69153
# 1           P2          -10.0                                       69153
# 2           P3          -20.0                                       69153
# 3           P4           20.0                                       69153
#
#    Normalized_TotalCerealsandMinorMillets_Production_old  \
# 0                                           0.012664
# 1                                           0.012664
# 2                                           0.012664
# 3                                           0.012664
#
#    TotalCerealsandMinorMillets_Production_new  \
# 0                               213098.682566
# 1                               187084.713490
# 2                               174077.728952
# 3                               226105.667105
#
#    Normalized_TotalCerealsandMinorMillets_Production_new  \
# 0                                           0.147046
# 1                                           0.122760
# 2                                           0.110618
# 3                                           0.159189
#
#    Change_in_TotalCerealsandMinorMillets_Production    Impact
# 0                                     143945.682566  0.134382
# 1                                     117931.713490  0.110097
# 2                                     104924.728952  0.097954
# 3                                     156952.667105  0.146525

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

def district_analysis(file_path, variable1, variable2, user_perturbations):
    # Load the dataset
    data = pd.read_csv(file_path)

    # Performing linear regression on the entire dataset
    X = data[[variable1]]
    y = data[variable2]
    model = LinearRegression()
    model.fit(X, y)
    m = model.coef_[0]  # Slope
    c = model.intercept_  # Intercept

    # User provided perturbations in percentages
    perturbations_corrected = [p / 100.0 for p in user_perturbations]

    # Min-max normalization parameters for variable2
    variable2_min = y.min()
    variable2_max = y.max()

    # Loop through each unique district in the dataset
    for district in data['District'].unique():
        district_variable1 = data.loc[data['District'] == district, variable1].iloc[0]
        variable2_old = data.loc[data['District'] == district, variable2].iloc[0]
        normalized_variable2_old = (variable2_old - variable2_min) / (variable2_max - variable2_min)

        district_results = []

        # Applying perturbations and calculating new values for each perturbation
        for p in perturbations_corrected:
            perturbed_variable1 = district_variable1 * (1 + p)
            variable2_new = m * perturbed_variable1 + c
            normalized_variable2_new = (variable2_new - variable2_min) / (variable2_max - variable2_min)
            change_in_variable2 = variable2_new - variable2_old
            impact = normalized_variable2_new - normalized_variable2_old

            district_results.append({
                'Perturbation (%)': p * 100,
                f'{variable2}_old': variable2_old,
                f'Normalized_{variable2}_old': normalized_variable2_old,
                f'{variable2}_new': variable2_new,
                f'Normalized_{variable2}_new': normalized_variable2_new,
                f'Change_in_{variable2}': change_in_variable2,
                'Impact': impact
            })

        # Convert the district results into a DataFrame and print it
        district_df = pd.DataFrame(district_results)
        print(f"Results for {district}:")
        print(district_df)
        print("\n")  # Add a newline for better readability between districts

# Example Usage:
file_path = '/content/Agriculture_KAG_2016_17.csv'
variable1 = 'TotalNPK'
variable2 = 'TotalCerealsandMinorMillets_Production'
user_perturbations = [10, -10, -20, 20]
district_analysis(file_path, variable1, variable2, user_perturbations)
# Out:
# Results for BENGALURU:
#    Perturbation (%)  TotalCerealsandMinorMillets_Production_old  \
# 0              10.0                                       69153
# 1             -10.0                                       69153
# 2             -20.0                                       69153
# 3              20.0                                       69153
#
#    Normalized_TotalCerealsandMinorMillets_Production_old  \
# 0                                           0.012664
# 1                                           0.012664
# 2                                           0.012664
# 3                                           0.012664
#
#    TotalCerealsandMinorMillets_Production_new  \
# 0                               213098.682566
# 1                               187084.713490
# 2                               174077.728952
# 3                               226105.667105
#
#    Normalized_TotalCerealsandMinorMillets_Production_new  \
# 0                                           0.147046
# 1                                           0.122760
# 2                                           0.110618
# 3                                           0.159189
#
#    Change_in_TotalCerealsandMinorMillets_Production    Impact
# 0                                     143945.682566  0.134382
# 1                                     117931.713490  0.110097
# 2                                     104924.728952  0.097954
# 3                                     156952.667105  0.146525
#
#
# Results for BENGALURU(R):
#    Perturbation (%)  TotalCerealsandMinorMillets_Production_old  \
# 0              10.0                                      125232
# 1             -10.0                                      125232
# 2             -20.0                                      125232
# 3              20.0                                      125232
#
#    Normalized_TotalCerealsandMinorMillets_Production_old  \
# 0                                           0.065017
# 1                                           0.065017
# 2                                           0.065017
# 3                                           0.065017
#
#    TotalCerealsandMinorMillets_Production_new  \
# 0                               188233.635891
# 1                               166740.584392
# 2                               155994.058642
# 3                               198980.161640
#
#    Normalized_TotalCerealsandMinorMillets_Production_new  \
# 0                                           0.123833
# 1                                           0.103768
# 2                                           0.093735
# 3                                           0.133866
#
#    Change_in_TotalCerealsandMinorMillets_Production    Impact
# 0                                      63001.635891  0.058816
# 1                                      41508.584392  0.038751
# 2                                      30762.058642  0.028718
# 3                                      73748.161640  0.068849
#
#
# Results for RAMANAGARA:
#    Perturbation (%)  TotalCerealsandMinorMillets_Production_old  \
# 0              10.0                                      159008
# 1             -10.0                                      159008
# 2             -20.0                                      159008
# 3              20.0                                      159008
#
#    Normalized_TotalCerealsandMinorMillets_Production_old  \
# 0                                           0.096549
# 1                                           0.096549
# 2                                           0.096549
# 3                                           0.096549
#
#    TotalCerealsandMinorMillets_Production_new  \
# 0                               115885.004647
# 1                               107546.249738
# 2                               103376.872283
# 3                               120054.382102
#
#    Normalized_TotalCerealsandMinorMillets_Production_new  \
# 0                                           0.056291
# 1                                           0.048506
# 2                                           0.044614
# 3                                           0.060183
#
#    Change_in_TotalCerealsandMinorMillets_Production    Impact
# 0                                     -43122.995353 -0.040258
# 1                                     -51461.750262 -0.048043
# 2                                     -55631.127717 -0.051935
# 3                                     -38953.617898 -0.036366
#
#
# Results for CHITRADURGA:
#    Perturbation (%)  TotalCerealsandMinorMillets_Production_old  \
# 0              10.0                                      388849
# 1             -10.0                                      388849
# 2             -20.0                                      388849
# 3              20.0                                      388849
#
#    Normalized_TotalCerealsandMinorMillets_Production_old  \
# 0                                            0.31112
# 1                                            0.31112
# 2                                            0.31112
# 3                                            0.31112
#
#    TotalCerealsandMinorMillets_Production_new  \
# 0                               290277.921495
# 1                               250231.363523
# 2                               230208.084536
# 3                               310301.200482
#
#    Normalized_TotalCerealsandMinorMillets_Production_new  \
# 0                                           0.219098
# 1                                           0.181712
# 2                                           0.163019
# 3                                           0.237791
#
#    Change_in_TotalCerealsandMinorMillets_Production    Impact
# 0                                     -98571.078505 -0.092022
# 1                                    -138617.636477 -0.129408
# 2                                    -158640.915464 -0.148101
# 3                                     -78547.799518 -0.073329
#
#
# Results for DAVANAGERE:
#    Perturbation (%)  TotalCerealsandMinorMillets_Production_old  \
# 0              10.0                                     1126753
# 1             -10.0                                     1126753
# 2             -20.0                                     1126753
# 3              20.0                                     1126753
#
#    Normalized_TotalCerealsandMinorMillets_Production_old  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                1.0
#
#    TotalCerealsandMinorMillets_Production_new  \
# 0                               681636.938045
# 1                               570434.195245
# 2                               514832.823845
# 3                               737238.309445
#
#    Normalized_TotalCerealsandMinorMillets_Production_new  \
# 0                                           0.584456
# 1                                           0.480641
# 2                                           0.428734
# 3                                           0.636364
#
#    Change_in_TotalCerealsandMinorMillets_Production    Impact
# 0                                    -445116.061955 -0.415544
# 1                                    -556318.804755 -0.519359
# 2                                    -611920.176155 -0.571266
# 3                                    -389514.690555 -0.363636
#
#
# Results for KOLAR:
#    Perturbation (%)  TotalCerealsandMinorMillets_Production_old  \
# 0              10.0                                       69089
# 1             -10.0                                       69089
# 2             -20.0                                       69089
# 3              20.0                                       69089
#
#    Normalized_TotalCerealsandMinorMillets_Production_old  \
# 0                                           0.012604
# 1                                           0.012604
# 2                                           0.012604
# 3                                           0.012604
#
#    TotalCerealsandMinorMillets_Production_new  \
# 0                               206224.120168
# 1                               181460.071527
# 2                               169078.047207
# 3                               218606.144488
#
#    Normalized_TotalCerealsandMinorMillets_Production_new  \
# 0                                           0.140628
# 1                                           0.117510
# 2                                           0.105950
# 3                                           0.152188
#
#    Change_in_TotalCerealsandMinorMillets_Production    Impact
# 0                                     137135.120168  0.128024
# 1                                     112371.071527  0.104905
# 2                                      99989.047207  0.093346
# 3                                     149517.144488  0.139584
#
#
# Results for CHIKKABALLAPURA:
#    Perturbation (%)  TotalCerealsandMinorMillets_Production_old  \
# 0              10.0                                      165723
# 1             -10.0                                      165723
# 2             -20.0                                      165723
# 3              20.0                                      165723
#
#    Normalized_TotalCerealsandMinorMillets_Production_old  \
# 0                                           0.102818
# 1                                           0.102818
# 2                                           0.102818
# 3                                           0.102818
#
#    TotalCerealsandMinorMillets_Production_new  \
# 0                               244077.179375
# 1                               212430.756333
# 2                               196607.544813
# 3                               259900.390896
#
#    Normalized_TotalCerealsandMinorMillets_Production_new  \
# 0                                           0.175967
# 1                                           0.146423
# 2                                           0.131651
# 3                                           0.190738
#
#    Change_in_TotalCerealsandMinorMillets_Production    Impact
# 0                                      78354.179375  0.073149
# 1                                      46707.756333  0.043605
# 2                                      30884.544813  0.028833
# 3                                      94177.390896  0.087921
#
#
# Results for SHIVAMOGGA:
#    Perturbation (%)  TotalCerealsandMinorMillets_Production_old  \
# 0              10.0                                      613331
# 1             -10.0                                      613331
# 2             -20.0                                      613331
# 3              20.0                                      613331
#
#    Normalized_TotalCerealsandMinorMillets_Production_old  \
# 0                                           0.520688
# 1                                           0.520688
# 2                                           0.520688
# 3                                           0.520688
#
#    TotalCerealsandMinorMillets_Production_new  \
# 0                               417488.015880
# 1                               354312.349838
# 2                               322724.516816
# 3                               449075.848902
#
#    Normalized_TotalCerealsandMinorMillets_Production_new  \
# 0                                           0.337856
# 1                                           0.278878
# 2                                           0.249389
# 3                                           0.367346
#
#    Change_in_TotalCerealsandMinorMillets_Production    Impact
# 0                                    -195842.984120 -0.182832
# 1                                    -259018.650162 -0.241810
# 2                                    -290606.483184 -0.271299
# 3                                    -164255.151098 -0.153343
#
#
# Results for TUMAKURU:
#    Perturbation (%)  TotalCerealsandMinorMillets_Production_old  \
# 0              10.0                                      431562
# 1             -10.0                                      431562
# 2             -20.0                                      431562
# 3              20.0                                      431562
#
#    Normalized_TotalCerealsandMinorMillets_Production_old  \
# 0                                           0.350995
# 1                                           0.350995
# 2                                           0.350995
# 3                                           0.350995
#
#    TotalCerealsandMinorMillets_Production_new  \
# 0                               304174.358344
# 1                               261601.175490
# 2                               240314.584062
# 3                               325460.949771
#
#    Normalized_TotalCerealsandMinorMillets_Production_new  \
# 0                                           0.232071
# 1                                           0.192326
# 2                                           0.172454
# 3                                           0.251943
#
#    Change_in_TotalCerealsandMinorMillets_Production    Impact
# 0                                    -127387.641656 -0.118924
# 1                                    -169960.824510 -0.158669
# 2                                    -191247.415938 -0.178542
# 3                                    -106101.050229 -0.099052
#
#
# Results for CHIKKAMAGALURU:
#    Perturbation (%)  TotalCerealsandMinorMillets_Production_old  \
# 0              10.0                                      235695
# 1             -10.0                                      235695
# 2             -20.0                                      235695
# 3              20.0                                      235695
#
#    Normalized_TotalCerealsandMinorMillets_Production_old  \
# 0                                           0.168141
# 1                                           0.168141
# 2                                           0.168141
# 3                                           0.168141
#
#    TotalCerealsandMinorMillets_Production_new  \
# 0                
#
#    Change_in_TotalCerealsandMinorMillets_Production    Impact
# 0                                     339591.730366  0.317030
# 1                                     237601.570781  0.221816
# 2                                     186606.490988  0.174209
# 3                                     390586.810159  0.364637
#
#
# Results for RAICHUR:
#    Perturbation (%)  TotalCerealsandMinorMillets_Production_old  \
# 0              10.0                                      622361
# 1             -10.0                                      622361
# 2             -20.0                                      622361
# 3              20.0                                      622361
#
#    Normalized_TotalCerealsandMinorMillets_Production_old  \
# 0                                           0.529118
# 1                                           0.529118
# 2                                           0.529118
# 3                                           0.529118
#
#    TotalCerealsandMinorMillets_Production_new  \
# 0                               789610.533719
# 1                               658776.228069
# 2                               593359.075244
# 3                               855027.686544
#
#    Normalized_TotalCerealsandMinorMillets_Production_new  \
# 0                                           0.685256
# 1                                           0.563114
# 2                                           0.502043
# 3                                           0.746327
#
#    Change_in_TotalCerealsandMinorMillets_Production    Impact
# 0                                     167249.533719  0.156138
# 1                                      36415.228069  0.033996
# 2                                     -29001.924756 -0.027075
# 3                                     232666.686544  0.217209
#
#
# Results for KOPPAL:
#    Perturbation (%)  TotalCerealsandMinorMillets_Production_old  \
# 0              10.0                                      565846
# 1             -10.0                                      565846
# 2             -20.0                                      565846
# 3              20.0                                      565846
#
#    Normalized_TotalCerealsandMinorMillets_Production_old  \
# 0                                           0.476358
# 1                                           0.476358
# 2                                           0.476358
# 3                                           0.476358
#
#    TotalCerealsandMinorMillets_Production_new  \
# 0                               521484.186166
# 1                               439400.125526
# 2                               398358.095206
# 3                               562526.216486
#
#    Normalized_TotalCerealsandMinorMillets_Production_new  \
# 0                                           0.434943
# 1                                           0.358313
# 2                                           0.319997
# 3                                           0.473259
#
#    Change_in_TotalCerealsandMinorMillets_Production    Impact
# 0                                     -44361.813834 -0.041415
# 1                                    -126445.874474 -0.118045
# 2                                    -167487.904794 -0.156361
# 3                                      -3319.783514 -0.003099

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

def bar_graph_analysis(file_path, variable1, variable2, user_perturbations):
    # Load the dataset
    data = pd.read_csv(file_path)

    # Performing linear regression on the entire dataset
    X = data[[variable1]]
    y = data[variable2]
    model = LinearRegression()
    model.fit(X, y)
    m = model.coef_[0]  # Slope
    c = model.intercept_  # Intercept

    # User provided perturbations in percentages
    perturbations_corrected = [p / 100.0 for p in user_perturbations]

    # Min-max normalization parameters for variable2
    variable2_min = y.min()
    variable2_max = y.max()

    # Loop through each unique district in the dataset
    for district in data['District'].unique():
        district_variable1 = data.loc[data['District'] == district, variable1].iloc[0]
        variable2_old = data.loc[data['District'] == district, variable2].iloc[0]
        normalized_old = (variable2_old - variable2_min) / (variable2_max - variable2_min)

        impacts = []

        for p in perturbations_corrected:
            perturbed_variable1 = district_variable1 * (1 + p)
            variable2_new = m * perturbed_variable1 + c
            normalized_new = (variable2_new - variable2_min) / (variable2_max - variable2_min)
            impact = (normalized_new - normalized_old) * 100  # Impact calculation
            impacts.append(impact)

        # Plotting the impacts of each perturbation
        plt.figure(figsize=(10, 6))
        plt.bar([f'{p*100:+.0f}%' for p in perturbations_corrected], impacts, color='skyblue')
        plt.xlabel('Perturbation (Magnitude in %)')
        plt.ylabel('Impact')
        plt.title(f'Impact of Perturbations on {variable2} for {district}')
        plt.axhline(0, color='gray', linewidth=0.8)
        plt.grid(axis='y', linestyle='--', alpha=0.7)
        plt.show()

# Example Usage:
file_path = '/content/Agriculture_KAG_2016_17.csv'
variable1 = 'TotalNPK'
variable2 = 'TotalCerealsandMinorMillets_Production'
user_perturbations = [10, -10, -20, 20]
bar_graph_analysis(file_path, variable1, variable2, user_perturbations)

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

def choose_perturbation(file_path, variable1, variable2, user_perturbations):
    # Load the dataset
    data = pd.read_csv(file_path)

    # Performing linear regression on the entire dataset
    X = data[[variable1]]
    y = data[variable2]
    model = LinearRegression()
    model.fit(X, y)
    m = model.coef_[0]  # Slope
    c = model.intercept_  # Intercept

    # User provided perturbations in percentages
    perturbations_corrected = [p / 100.0 for p in user_perturbations]

    # Min-max normalization parameters for variable2
    variable2_min = y.min()
    variable2_max = y.max()

    # Initialize an empty list to store results for each district
    district_results = []

    # Loop through each unique district in the dataset
    for district in data['District'].unique():
        district_variable1 = data.loc[data['District'] == district, variable1].iloc[0]
        variable2_old = data.loc[data['District'] == district, variable2].iloc[0]
        normalized_old = (variable2_old - variable2_min) / (variable2_max - variable2_min)

        positive_impacts = []
        negative_impacts = []

        for p in perturbations_corrected:
            perturbed_variable1 = district_variable1 * (1 + p)
            variable2_new = m * perturbed_variable1 + c
            normalized_new = (variable2_new - variable2_min) / (variable2_max - variable2_min)
            impact = (normalized_new - normalized_old) * 100  # Impact calculation

            if impact > 0:
                positive_impacts.append((impact, p))
            elif impact < 0:
                negative_impacts.append((impact, p))

        # Choose perturbation based on conditions
        if positive_impacts and not negative_impacts:
            chosen_perturbation = max(positive_impacts)[1]
        elif not positive_impacts and negative_impacts:
            chosen_perturbation = min(negative_impacts)[1]
        elif positive_impacts and negative_impacts:
            chosen_perturbation = max(positive_impacts)[1]

        district_results.append({
            'District': district,
            'Perturbation_Choosen': f'P{user_perturbations.index(chosen_perturbation*100)+1}'
        })

    # Convert the results into a DataFrame and display
    results_df = pd.DataFrame(district_results)
    print(results_df)

# Example Usage:
file_path = '/content/Agriculture_KAG_2016_17.csv'
variable1 = 'TotalNPK'
variable2 = 'Rice_Production'
user_perturbations = [10, -10, -20, 20]
choose_perturbation(file_path, variable1, variable2, user_perturbations)
# Out:
#             District Perturbation_Choosen
# 0          BENGALURU                   P4
# 1       BENGALURU(R)                   P4
# 2         RAMANAGARA                   P4
# 3        CHITRADURGA                   P4
# 4         DAVANAGERE                   P3
# 5              KOLAR                   P4
# 6    CHIKKABALLAPURA                   P4
# 7         SHIVAMOGGA                   P3
# 8           TUMAKURU                   P4
# 9     CHIKKAMAGALURU                   P4
# 10  DAKSHINA KANNADA                   P3
# 11             UDUPI                   P3
# 12            HASSAN                   P4
# 13            KODAGU                   P4
# 14            MANDYA                   P3
# 15            MYSURU                   P3
# 16    CHAMARAJANAGAR                   P4
# 17          BELAGAVI                   P4
# 18        VIJAYAPURA                   P4
# 19          BAGALKOT                   P4
# 20          DHARAWAD                   P4
# 21             GADAG                   P4
# 22            HAVERI                   P4
# 23    UTTARA KANNADA                   P3
# 24           BALLARI                   P3
# 25             BIDAR                   P4
# 26        KALABURAGI                   P4
# 27           YADGIRI                   P4
# 28           RAICHUR                   P3
# 29            KOPPAL                   P3
