# %% [markdown]
# <a href="https://colab.research.google.com/github/Annie-blare/WSL_LAB/blob/main/Copy_of_Jowar_Yield.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

def individual_analysis(file_path, district_name, variable1, variable2, user_perturbations):
    # Load the dataset
    data = pd.read_csv(file_path)

    # Selecting the specified variables
    X = data[[variable1]]
    y = data[variable2]

    # Performing linear regression
    model = LinearRegression()
    model.fit(X, y)
    m = model.coef_[0]  # Slope
    c = model.intercept_  # Intercept

    # Extracting variable1 for the specified district
    district_variable1 = data.loc[data['District'] == district_name, variable1].iloc[0]

    # User provided perturbations in percentages
    perturbations_corrected = [p / 100.0 for p in user_perturbations]

    # Calculating variable2(old) for the specified district
    variable2_old = data.loc[data['District'] == district_name, variable2].iloc[0]

    # Min-max normalization for variable2(old)
    variable2_min = y.min()
    variable2_max = y.max()
    normalized_variable2_old = (variable2_old - variable2_min) / (variable2_max - variable2_min)

    # Applying corrected perturbations and calculating new values
    results_corrected = []
    for p in perturbations_corrected:
        perturbed_variable1 = district_variable1 * (1 + p)
        variable2_new = m * perturbed_variable1 + c
        normalized_variable2_new = (variable2_new - variable2_min) / (variable2_max - variable2_min)
        change_in_variable2 = variable2_new - variable2_old
        impact = normalized_variable2_new - normalized_variable2_old

        results_corrected.append({
            'Perturbation': f'P{user_perturbations.index(p*100)+1}',
            'Magnitude (%)': p*100,
            f'{variable2}_old': variable2_old,
            f'Normalized_{variable2}_old': normalized_variable2_old,
            f'{variable2}_new': variable2_new,
            f'Normalized_{variable2}_new': normalized_variable2_new,
            f'Change_in_{variable2}': change_in_variable2,
            'Impact': impact
        })

    results_df_corrected = pd.DataFrame(results_corrected)
    print(results_df_corrected)

# Example Usage:
file_path = '/content/Agriculture_KAG_2016_17.csv'
district_name = 'BENGALURU'
variable1 = 'TotalNPK'
variable2 = 'Jowar_Yield'
user_perturbations = [10, -10, -20, 20]
individual_analysis(file_path, district_name, variable1, variable2, user_perturbations)
# Out:
#   Perturbation  Magnitude (%)  Jowar_Yield_old  Normalized_Jowar_Yield_old  \
# 0           P1           10.0             1539                    0.686441
# 1           P2          -10.0             1539                    0.686441
# 2           P3          -20.0             1539                    0.686441
# 3           P4           20.0             1539                    0.686441
#
#    Jowar_Yield_new  Normalized_Jowar_Yield_new  Change_in_Jowar_Yield  \
# 0       616.168067                    0.274830            -922.831933
# 1       570.414310                    0.254422            -968.585690
# 2       547.537431                    0.244218            -991.462569
# 3       639.044946                    0.285033            -899.955054
#
#      Impact
# 0 -0.411611
# 1 -0.432019
# 2 -0.442222
# 3 -0.401407

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

def district_analysis(file_path, variable1, variable2, user_perturbations):
    # Load the dataset
    data = pd.read_csv(file_path)

    # Performing linear regression on the entire dataset
    X = data[[variable1]]
    y = data[variable2]
    model = LinearRegression()
    model.fit(X, y)
    m = model.coef_[0]  # Slope
    c = model.intercept_  # Intercept

    # User provided perturbations in percentages
    perturbations_corrected = [p / 100.0 for p in user_perturbations]

    # Min-max normalization parameters for variable2
    variable2_min = y.min()
    variable2_max = y.max()

    # Loop through each unique district in the dataset
    for district in data['District'].unique():
        district_variable1 = data.loc[data['District'] == district, variable1].iloc[0]
        variable2_old = data.loc[data['District'] == district, variable2].iloc[0]
        normalized_variable2_old = (variable2_old - variable2_min) / (variable2_max - variable2_min)

        district_results = []

        # Applying perturbations and calculating new values for each perturbation
        for p in perturbations_corrected:
            perturbed_variable1 = district_variable1 * (1 + p)
            variable2_new = m * perturbed_variable1 + c
            normalized_variable2_new = (variable2_new - variable2_min) / (variable2_max - variable2_min)
            change_in_variable2 = variable2_new - variable2_old
            impact = normalized_variable2_new - normalized_variable2_old

            district_results.append({
                'Perturbation (%)': p * 100,
                f'{variable2}_old': variable2_old,
                f'Normalized_{variable2}_old': normalized_variable2_old,
                f'{variable2}_new': variable2_new,
                f'Normalized_{variable2}_new': normalized_variable2_new,
                f'Change_in_{variable2}': change_in_variable2,
                'Impact': impact
            })

        # Convert the district results into a DataFrame and print it
        district_df = pd.DataFrame(district_results)
        print(f"Results for {district}:")
        print(district_df)
        print("\n")  # Add a newline for better readability between districts

# Example Usage:
file_path = '/content/Agriculture_KAG_2016_17.csv'
variable1 = 'TotalNPK'
variable2 = 'Jowar_Yield'
user_perturbations = [10, -10, -20, 20]
district_analysis(file_path, variable1, variable2, user_perturbations)
# Out:
# Results for BENGALURU:
#    Perturbation (%)  Jowar_Yield_old  Normalized_Jowar_Yield_old  \
# 0              10.0             1539                    0.686441
# 1             -10.0             1539                    0.686441
# 2             -20.0             1539                    0.686441
# 3              20.0             1539                    0.686441
#
#    Jowar_Yield_new  Normalized_Jowar_Yield_new  Change_in_Jowar_Yield  \
# 0       616.168067                    0.274830            -922.831933
# 1       570.414310                    0.254422            -968.585690
# 2       547.537431                    0.244218            -991.462569
# 3       639.044946                    0.285033            -899.955054
#
#      Impact
# 0 -0.411611
# 1 -0.432019
# 2 -0.442222
# 3 -0.401407
#
#
# Results for BENGALURU(R):
#    Perturbation (%)  Jowar_Yield_old  Normalized_Jowar_Yield_old  \
# 0              10.0                0                         0.0
# 1             -10.0                0                         0.0
# 2             -20.0                0                         0.0
# 3              20.0                0                         0.0
#
#    Jowar_Yield_new  Normalized_Jowar_Yield_new  Change_in_Jowar_Yield  \
# 0       572.435052                    0.255323             572.435052
# 1       534.632751                    0.238462             534.632751
# 2       515.731601                    0.230032             515.731601
# 3       591.336202                    0.263754             591.336202
#
#      Impact
# 0  0.255323
# 1  0.238462
# 2  0.230032
# 3  0.263754
#
#
# Results for RAMANAGARA:
#    Perturbation (%)  Jowar_Yield_old  Normalized_Jowar_Yield_old  \
# 0              10.0                0                         0.0
# 1             -10.0                0                         0.0
# 2             -20.0                0                         0.0
# 3              20.0                0                         0.0
#
#    Jowar_Yield_new  Normalized_Jowar_Yield_new  Change_in_Jowar_Yield  \
# 0       445.187197                    0.198567             445.187197
# 1       430.520870                    0.192025             430.520870
# 2       423.187707                    0.188755             423.187707
# 3       452.520360                    0.201838             452.520360
#
#      Impact
# 0  0.198567
# 1  0.192025
# 2  0.188755
# 3  0.201838
#
#
# Results for CHITRADURGA:
#    Perturbation (%)  Jowar_Yield_old  Normalized_Jowar_Yield_old  \
# 0              10.0              984                    0.438894
# 1             -10.0              984                    0.438894
# 2             -20.0              984                    0.438894
# 3              20.0              984                    0.438894
#
#    Jowar_Yield_new  Normalized_Jowar_Yield_new  Change_in_Jowar_Yield  \
# 0       751.912067                    0.335376            -232.087933
# 1       681.477582                    0.303960            -302.522418
# 2       646.260340                    0.288252            -337.739660
# 3       787.129310                    0.351084            -196.870690
#
#      Impact
# 0 -0.103518
# 1 -0.134934
# 2 -0.150642
# 3 -0.087810
#
#
# Results for DAVANAGERE:
#    Perturbation (%)  Jowar_Yield_old  Normalized_Jowar_Yield_old  \
# 0              10.0             2167                    0.966548
# 1             -10.0             2167                    0.966548
# 2             -20.0             2167                    0.966548
# 3              20.0             2167                    0.966548
#
#    Jowar_Yield_new  Normalized_Jowar_Yield_new  Change_in_Jowar_Yield  \
# 0      1440.240158                    0.642391            -726.759842
# 1      1244.655111                    0.555154            -922.344889
# 2      1146.862588                    0.511535           -1020.137412
# 3      1538.032682                    0.686009            -628.967318
#
#      Impact
# 0 -0.324157
# 1 -0.411394
# 2 -0.455012
# 3 -0.280539
#
#
# Results for KOLAR:
#    Perturbation (%)  Jowar_Yield_old  Normalized_Jowar_Yield_old  \
# 0              10.0                0                         0.0
# 1             -10.0                0                         0.0
# 2             -20.0                0                         0.0
# 3              20.0                0                         0.0
#
#    Jowar_Yield_new  Normalized_Jowar_Yield_new  Change_in_Jowar_Yield  \
# 0       604.076984                    0.269437             604.076984
# 1       560.521605                    0.250010             560.521605
# 2       538.743916                    0.240296             538.743916
# 3       625.854674                    0.279150             625.854674
#
#      Impact
# 0  0.269437
# 1  0.250010
# 2  0.240296
# 3  0.279150
#
#
# Results for CHIKKABALLAPURA:
#    Perturbation (%)  Jowar_Yield_old  Normalized_Jowar_Yield_old  \
# 0              10.0                0                         0.0
# 1             -10.0                0                         0.0
# 2             -20.0                0                         0.0
# 3              20.0                0                         0.0
#
#    Jowar_Yield_new  Normalized_Jowar_Yield_new  Change_in_Jowar_Yield  \
# 0       670.653511                    0.299132             670.653511
# 1       614.993309                    0.274306             614.993309
# 2       587.163208                    0.261893             587.163208
# 3       698.483612                    0.311545             698.483612
#
#      Impact
# 0  0.299132
# 1  0.274306
# 2  0.261893
# 3  0.311545
#
#
# Results for SHIVAMOGGA:
#    Perturbation (%)  Jowar_Yield_old  Normalized_Jowar_Yield_old  \
# 0              10.0             2242                         1.0
# 1             -10.0             2242                         1.0
# 2             -20.0             2242                         1.0
# 3              20.0             2242                         1.0
#
#    Jowar_Yield_new  Normalized_Jowar_Yield_new  Change_in_Jowar_Yield  \
# 0       975.651084                    0.435170           -1266.348916
# 1       864.536777                    0.385610           -1377.463223
# 2       808.979624                    0.360829           -1433.020376
# 3      1031.208237                    0.459950           -1210.791763
#
#      Impact
# 0 -0.564830
# 1 -0.614390
# 2 -0.639171
# 3 -0.540050
#
#
# Results for TUMAKURU:
#    Perturbation (%)  Jowar_Yield_old  Normalized_Jowar_Yield_old  \
# 0              10.0             1346                    0.600357
# 1             -10.0             1346                    0.600357
# 2             -20.0             1346                    0.600357
# 3              20.0             1346                    0.600357
#
#    Jowar_Yield_new  Normalized_Jowar_Yield_new  Change_in_Jowar_Yield  \
# 0       776.353328                    0.346277            -569.646672
# 1       701.474977                    0.312879            -644.525023
# 2       664.035802                    0.296180            -681.964198
# 3       813.792503                    0.362976            -532.207497
#
#      Impact
# 0 -0.254080
# 1 -0.287478
# 2 -0.304177
# 3 -0.237381
#
#
# Results for CHIKKAMAGALURU:
#    Perturbation (%)  Jowar_Yield_old  Normalized_Jowar_Yield_old  \
# 0              10.0              897                    0.400089
# 1             -10.0              897                    0.400089
# 2             -20.0              897                    0.400089
# 3              20.0              897                    0.400089
#
#    Jowar_Yield_new  Normalized_Jowar_Yield_new  Change_in_Jowar_Yield  \
# 0      1097.144878                    0.489360             200.144878
# 1       963.940791                    0.429947              66.940791
# 2       897.338747                    0.400240               0.338747
# 3      1163.746922                    0.519066             266.746922
#
#      Impact
# 0  0.089271
# 1  0.029858
# 2  0.000151
# 3  0.118977
#
#
# Results for DAKSHINA KANNADA:
#    Perturbation (%)  Jowar_Yield_old  Normalized_Jowar_Yield_old  \
# 0              10.0                0                         0.0
# 1             -10.0                0                         0.0
# 2             -20.0                0                         0.0
# 3              20.0                0                         0.0
#
#    Jowar_Yield_new  Normalized_Jowar_Yield_new  Change_in_Jowar_Yield  \
# 0       565.191197                    0.252092             565.191197
# 1       528.705961                    0.235819             528.705961
# 2       510.463343                    0.227682             510.463343
# 3       583.433815                    0.260229             583.433815
#
#      Impact
# 0  0.252092
# 1  0.235819
# 2  0.227682
# 3  0.260229
#
#
# Results for UDUPI:
#    Perturbation (%)  Jowar_Yield_old  Normalized_Jowar_Yield_old  \
# 0              10.0                0                         0.0
# 1             -10.0                0                         0.0
# 2             -20.0                0                         0.0
# 3              20.0                0                         0.0
#
#    Jowar_Yield_new  Normalized_Jowar_Yield_new  Change_in_Jowar_Yield  \
# 0       430.893809                    0.192192             430.893809
# 1       418.826280                    0.186809             418.826280
# 2       412.792516                    0.184118             412.792516
# 3       436.927574                    0.194883             436.927574
#
#      Impact
# 0  0.192192
# 1  0.186809
# 2  0.184118
# 3  0.194883
#
#
# Results for HASSAN:
#    Perturbation (%)  Jowar_Yield_old  Normalized_Jowar_Yield_old  \
# 0              10.0              917                     0.40901
# 1             -10.0              917                     0.40901
# 2             -20.0              917                     0.40901
# 3              20.0              917                     0.40901
#
#    Jowar_Yield_new  Normalized_Jowar_Yield_new  Change_in_Jowar_Yield  \
# 0      1103.276785                    0.492095             186.276785
# 1       968.957805                    0.432185              51.957805
# 2       901.798316                    0.402229             -15.201684
# 3      1170.436274                    0.522050             253.436274
#
#      Impact
# 0  0.083085
# 1  0.023175
# 2 -0.006780
# 3  0.113040
#
#
# Results for KODAGU:
#    Perturbation (%)  Jowar_Yield_old  Normalized_Jowar_Yield_old  \
# 0              10.0                0                         0.0
# 1             -10.0                0                         0.0
# 2             -20.0                0                         0.0
# 3              20.0                0                         0.0
#
#    Jowar_Yield_new  Normalized_Jowar_Yield_new  Change_in_Jowar_Yield  \
# 0       806.570240                    0.359755             806.570240
# 1       726.197906                    0.323906             726.197906
# 2       686.011738                    0.305982             686.011738
# 3       846.756408                    0.377679             846.756408
#
#      Impact
# 0  0.359755
# 1  0.323906
# 2  0.305982
# 3  0.377679
#
#
# Results for MANDYA:
#    Perturbation (%)  Jowar_Yield_old  Normalized_Jowar_Yield_old  \
# 0              10.0              970                    0.432649
# 1             -10.0              970                    0.432649
# 2             -20.0              970                    0.432649
# 3              20.0              970                    0.432649
#
#    Jowar_Yield_new  Normalized_Jowar_Yield_new  Change_in_Jowar_Yield  \
# 0      1018.282947                    0.454185              48.282947
# 1       899.417393                    0.401167             -70.582607
# 2       839.984616                    0.374659            -130.015384
# 3      1077.715724                    0.480694             107.715724
#
#      Impact
# 0  0.021536
# 1 -0.031482
# 2 -0.057991
# 3  0.048044
#
#
# Results for MYSURU:
#    Perturbation (%)  Jowar_Yield_old  Normalized_Jowar_Yield_old  \
# 0              10.0             1104                    0.492417
# 1             -10.0             1104                    0.492417
# 2             -20.0             1104                    0.492417
# 3              20.0             1104                    0.492417
#
#    Jowar_Yield_new  Normalized_Jowar_Yield_new  Change_in_Jowar_Yield  \
# 0      1034.001355                    0.461196             -69.998645
# 1       912.277909                    0.406904            -191.722091
# 2       851.416186                    0.379757            -252.583814
# 3      1094.863079                    0.488342              -9.136921
#
#      Impact
# 0 -0.031222
# 1 -0.085514
# 2 -0.112660
# 3 -0.004075
#
#
# Results for CHAMARAJANAGAR:
#    Perturbation (%)  Jowar_Yield_old  Normalized_Jowar_Yield_old  \
# 0              10.0              371                    0.165477
# 1             -10.0              371                    0.165477
# 2             -20.0              371                    0.165477
# 3              20.0              371                    0.165477
#
#    Jowar_Yield_new  Normalized_Jowar_Yield_new  Change_in_Jowar_Yield  \
# 0       621.490303                    0.277204             250.490303
# 1       574.768866                    0.256364             203.768866
# 2       551.408148                    0.245945             180.408148
# 3       644.851022                    0.287623             273.851022
#
#      Impact
# 0  0.111726
# 1  0.090887
# 2  0.080468
# 3  0.122146
#
#
# Results for BELAGAVI:
#    Perturbation (%)  Jowar_Yield_old  Normalized_Jowar_Yield_old  \
# 0              10.0             1200                    0.535236
# 1             -10.0             1200                    0.535236
# 2             -20.0             1200                    0.535236
# 3              20.0             1200                    0.535236
#
#    Jowar_Yield_new  Normalized_Jowar_Yield_new  Change_in_Jowar_Yield  \
# 0      2307.645827                    1.029280            1107.645827
# 1      1954.350659                    0.871700             754.350659
# 2      1777.703074                    0.792909             577.703074
# 3      2484.293412                    1.108070            1284.293412
#
#      Impact
# 0  0.494044
# 1  0.336463
# 2  0.257673
# 3  0.572834
#
#
# Results for VIJAYAPURA:
#    Perturbation (%)  Jowar_Yield_old  Normalized_Jowar_Yield_old  \
# 0              10.0              974                    0.434434
# 1             -10.0              974                    0.434434
# 2             -20.0              974                    0.434434
# 3              20.0              974                    0.434434
#
#    Jowar_Yield_new  Normalized_Jowar_Yield_new  Change_in_Jowar_Yield  \
# 0       949.946736                    0.423705             -24.053264
# 1       843.505948                    0.376229            -130.494052
# 2       790.285553                    0.352491            -183.714447
# 3      1003.167131                    0.447443              29.167131
#
#      Impact
# 0 -0.010728
# 1 -0.058204
# 2 -0.081942
# 3  0.013009
#
#
# Results for BAGALKOT:
#    Perturbation (%)  Jowar_Yield_old  Normalized_Jowar_Yield_old  \
# 0              10.0              966                    0.430865
# 1             -10.0              966                    0.430865
# 2             -20.0              966                    0.430865
# 3              20.0              966                    0.430865
#
#    Jowar_Yield_new  Normalized_Jowar_Yield_new  Change_in_Jowar_Yield  \
# 0      1280.119671                    0.570972             314.119671
# 1      1113.647440                    0.496721             147.647440
# 2      1030.411324                    0.459595              64.411324
# 3      1363.355787                    0.608098             397.355787
#
#      Impact
# 0  0.140107
# 1  0.065855
# 2  0.028729
# 3  0.177233
#
#
# Results for DHARAWAD:
#    Perturbation (%)  Jowar_Yield_old  Normalized_Jowar_Yield_old  \
# 0              10.0             1080                    0.481713
# 1             -10.0             1080                    0.481713
# 2             -20.0             1080                    0.481713
# 3              20.0             1080                    0.481713
#
#    Jowar_Yield_new  Normalized_Jowar_Yield_new  Change_in_Jowar_Yield  \
# 0       768.073095                    0.342584            -311.926905
# 1       694.700241                    0.309857            -385.299759
# 2       658.013815                    0.293494            -421.986185
# 3       804.759522                    0.358947            -275.240478
#
#      Impact
# 0 -0.139129
# 1 -0.171855
# 2 -0.188219
# 3 -0.122766
#
#
# Results for GADAG:
#    Perturbation (%)  Jowar_Yield_old  Normalized_Jowar_Yield_old  \
# 0              10.0             1025                    0.457181
# 1             -10.0             1025                    0.457181
# 2             -20.0             1025                    0.457181
# 3              20.0             1025                    0.457181
#
#    Jowar_Yield_new  Normalized_Jowar_Yield_new  Change_in_Jowar_Yield  \
# 0       615.844199                    0.274685            -409.155801
# 1       570.149326                    0.254304            -454.850674
# 2       547.301890                    0.244113            -477.698110
# 3       638.691636                    0.284876            -386.308364
#
#      Impact
# 0 -0.182496
# 1 -0.202877
# 2 -0.213068
# 3 -0.172305
#
#
# Results for HAVERI:
#    Perturbation (%)  Jowar_Yield_old  Normalized_Jowar_Yield_old  \
# 0              10.0             1207                    0.538359
# 1             -10.0             1207                    0.538359
# 2             -20.0             1207                    0.538359
# 3              20.0             1207                    0.538359
#
#    Jowar_Yield_new  Normalized_Jowar_Yield_new  Change_in_Jowar_Yield  \
# 0      1066.247842                    0.475579            -140.752158
# 1       938.661398                    0.418671            -268.338602
# 2       874.868176                    0.390218            -332.131824
# 3      1130.041064                    0.504033             -76.958936
#
#      Impact
# 0 -0.062780
# 1 -0.119687
# 2 -0.148141
# 3 -0.034326
#
#
# Results for UTTARA KANNADA:
#    Perturbation (%)  Jowar_Yield_old  Normalized_Jowar_Yield_old  \
# 0              10.0                0                         0.0
# 1             -10.0                0                         0.0
# 2             -20.0                0                         0.0
# 3              20.0                0                         0.0
#
#    Jowar_Yield_new  Normalized_Jowar_Yield_new  Change_in_Jowar_Yield  \
# 0       529.867961                    0.236337             529.867961
# 1       499.805132                    0.222928             499.805132
# 2       484.773717                    0.216224             484.773717
# 3       544.899376                    0.243042             544.899376
#
#      Impact
# 0  0.236337
# 1  0.222928
# 2  0.216224
# 3  0.243042
#
#
# Results for BALLARI:
#    Perturbation (%)  Jowar_Yield_old  Normalized_Jowar_Yield_old  \
# 0              10.0             1807                    0.805977
# 1             -10.0             1807                    0.805977
# 2             -20.0             1807                    0.805977
# 3              20.0             1807                    0.805977
#
#    Jowar_Yield_new  Normalized_Jowar_Yield_new  Change_in_Jowar_Yield  \
# 0      1695.934180                    0.756438            -111.065820
# 1      1453.859311                    0.648465            -353.140689
# 2      1332.821876                    0.594479            -474.178124
# 3      1816.971615                    0.810424               9.971615
#
#      Impact
# 0 -0.049539
# 1 -0.157511
# 2 -0.211498
# 3  0.004448
#
#
# Results for BIDAR:
#    Perturbation (%)  Jowar_Yield_old  Normalized_Jowar_Yield_old  \
# 0              10.0             1058                      0.4719
# 1             -10.0             1058                      0.4719
# 2             -20.0             1058                      0.4719
# 3              20.0             1058                      0.4719
#
#    Jowar_Yield_new  Normalized_Jowar_Yield_new  Change_in_Jowar_Yield  \
# 0       630.720550                    0.281320            -427.279450
# 1       582.320886                    0.259733            -475.679114
# 2       558.121054                    0.248939            -499.878946
# 3       654.920382                    0.292114            -403.079618
#
#      Impact
# 0 -0.190580
# 1 -0.212167
# 2 -0.222961
# 3 -0.179786
#
#
# Results for KALABURAGI:
#    Perturbation (%)  Jowar_Yield_old  Normalized_Jowar_Yield_old  \
# 0              10.0             1146                    0.511151
# 1             -10.0             1146                    0.511151
# 2             -20.0             1146                    0.511151
# 3              20.0             1146                    0.511151
#
#    Jowar_Yield_new  Normalized_Jowar_Yield_new  Change_in_Jowar_Yield  \
# 0       947.474542                    0.422602            -198.525458
# 1       841.483243                    0.375327            -304.516757
# 2       788.487594                    0.351689            -357.512406
# 3      1000.470191                    0.446240            -145.529809
#
#      Impact
# 0 -0.088548
# 1 -0.135824
# 2 -0.159461
# 3 -0.064911
#
#
# Results for YADGIRI:
#    Perturbation (%)  Jowar_Yield_old  Normalized_Jowar_Yield_old  \
# 0              10.0             1197                    0.533898
# 1             -10.0             1197                    0.533898
# 2             -20.0             1197                    0.533898
# 3              20.0             1197                    0.533898
#
#    Jowar_Yield_new  Normalized_Jowar_Yield_new  Change_in_Jowar_Yield  \
# 0      1351.122398                    0.602642             154.122398
# 1      1171.740580                    0.522632             -25.259420
# 2      1082.049671                    0.482627            -114.950329
# 3      1440.813307                    0.642646             243.813307
#
#      Impact
# 0  0.068743
# 1 -0.011266
# 2 -0.051271
# 3  0.108748
#
#
# Results for RAICHUR:
#    Perturbation (%)  Jowar_Yield_old  Normalized_Jowar_Yield_old  \
# 0              10.0             1359                    0.606155
# 1             -10.0             1359                    0.606155
# 2             -20.0             1359                    0.606155
# 3              20.0             1359                    0.606155
#
#    Jowar_Yield_new  Normalized_Jowar_Yield_new  Change_in_Jowar_Yield  \
# 0      1630.145733                    0.727094             271.145733
# 1      1400.032400                    0.624457              41.032400
# 2      1284.975733                    0.573138             -74.024267
# 3      1745.202400                    0.778413             386.202400
#
#      Impact
# 0  0.120939
# 1  0.018302
# 2 -0.033017
# 3  0.172258
#
#
# Results for KOPPAL:
#    Perturbation (%)  Jowar_Yield_old  Normalized_Jowar_Yield_old  \
# 0              10.0             1312                    0.585192
# 1             -10.0             1312                    0.585192
# 2             -20.0             1312                    0.585192
# 3              20.0             1312                    0.585192
#
#    Jowar_Yield_new  Normalized_Jowar_Yield_new  Change_in_Jowar_Yield  \
# 0      1158.561103                    0.516753            -153.438897
# 1      1014.190430                    0.452360            -297.809570
# 2       942.005093                    0.420163            -369.994907
# 3      1230.746440                    0.548950             -81.253560
#
#      Impact
# 0 -0.068438
# 1 -0.132832
# 2 -0.165029
# 3 -0.036242

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

def bar_graph_analysis(file_path, variable1, variable2, user_perturbations):
    # Load the dataset
    data = pd.read_csv(file_path)

    # Performing linear regression on the entire dataset
    X = data[[variable1]]
    y = data[variable2]
    model = LinearRegression()
    model.fit(X, y)
    m = model.coef_[0]  # Slope
    c = model.intercept_  # Intercept

    # User provided perturbations in percentages
    perturbations_corrected = [p / 100.0 for p in user_perturbations]

    # Min-max normalization parameters for variable2
    variable2_min = y.min()
    variable2_max = y.max()

    # Loop through each unique district in the dataset
    for district in data['District'].unique():
        district_variable1 = data.loc[data['District'] == district, variable1].iloc[0]
        variable2_old = data.loc[data['District'] == district, variable2].iloc[0]
        normalized_old = (variable2_old - variable2_min) / (variable2_max - variable2_min)

        impacts = []

        for p in perturbations_corrected:
            perturbed_variable1 = district_variable1 * (1 + p)
            variable2_new = m * perturbed_variable1 + c
            normalized_new = (variable2_new - variable2_min) / (variable2_max - variable2_min)
            impact = (normalized_new - normalized_old) * 100  # Impact calculation
            impacts.append(impact)

        # Plotting the impacts of each perturbation
        plt.figure(figsize=(10, 6))
        plt.bar([f'{p*100:+.0f}%' for p in perturbations_corrected], impacts, color='skyblue')
        plt.xlabel('Perturbation (Magnitude in %)')
        plt.ylabel('Impact')
        plt.title(f'Impact of Perturbations on {variable2} for {district}')
        plt.axhline(0, color='gray', linewidth=0.8)
        plt.grid(axis='y', linestyle='--', alpha=0.7)
        plt.show()

# Example Usage:
file_path = '/content/Agriculture_KAG_2016_17.csv'
variable1 = 'TotalNPK'
variable2 = 'Jowar_Yield'
user_perturbations = [10, -10, -20, 20]
bar_graph_analysis(file_path, variable1, variable2, user_perturbations)

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

def choose_perturbation(file_path, variable1, variable2, user_perturbations):
    # Load the dataset
    data = pd.read_csv(file_path)

    # Performing linear regression on the entire dataset
    X = data[[variable1]]
    y = data[variable2]
    model = LinearRegression()
    model.fit(X, y)
    m = model.coef_[0]  # Slope
    c = model.intercept_  # Intercept

    # User provided perturbations in percentages
    perturbations_corrected = [p / 100.0 for p in user_perturbations]

    # Min-max normalization parameters for variable2
    variable2_min = y.min()
    variable2_max = y.max()

    # Initialize an empty list to store results for each district
    district_results = []

    # Loop through each unique district in the dataset
    for district in data['District'].unique():
        district_variable1 = data.loc[data['District'] == district, variable1].iloc[0]
        variable2_old = data.loc[data['District'] == district, variable2].iloc[0]
        normalized_old = (variable2_old - variable2_min) / (variable2_max - variable2_min)

        positive_impacts = []
        negative_impacts = []

        for p in perturbations_corrected:
            perturbed_variable1 = district_variable1 * (1 + p)
            variable2_new = m * perturbed_variable1 + c
            normalized_new = (variable2_new - variable2_min) / (variable2_max - variable2_min)
            impact = (normalized_new - normalized_old) * 100  # Impact calculation

            if impact > 0:
                positive_impacts.append((impact, p))
            elif impact < 0:
                negative_impacts.append((impact, p))

        # Choose perturbation based on conditions
        if positive_impacts and not negative_impacts:
            chosen_perturbation = max(positive_impacts)[1]
        elif not positive_impacts and negative_impacts:
            chosen_perturbation = min(negative_impacts)[1]
        elif positive_impacts and negative_impacts:
            chosen_perturbation = max(positive_impacts)[1]

        district_results.append({
            'District': district,
            'Perturbation_Choosen': f'P{user_perturbations.index(chosen_perturbation*100)+1}'
        })

    # Convert the results into a DataFrame and display
    results_df = pd.DataFrame(district_results)
    print(results_df)

# Example Usage:
file_path = '/content/Agriculture_KAG_2016_17.csv'
variable1 = 'TotalNPK'
variable2 = 'Jowar_Yield'
user_perturbations = [10, -10, -20, 20]
choose_perturbation(file_path, variable1, variable2, user_perturbations)
# Out:
#             District Perturbation_Choosen
# 0          BENGALURU                   P3
# 1       BENGALURU(R)                   P4
# 2         RAMANAGARA                   P4
# 3        CHITRADURGA                   P3
# 4         DAVANAGERE                   P3
# 5              KOLAR                   P4
# 6    CHIKKABALLAPURA                   P4
# 7         SHIVAMOGGA                   P3
# 8           TUMAKURU                   P3
# 9     CHIKKAMAGALURU                   P4
# 10  DAKSHINA KANNADA                   P4
# 11             UDUPI                   P4
# 12            HASSAN                   P4
# 13            KODAGU                   P4
# 14            MANDYA                   P4
# 15            MYSURU                   P3
# 16    CHAMARAJANAGAR                   P4
# 17          BELAGAVI                   P4
# 18        VIJAYAPURA                   P4
# 19          BAGALKOT                   P4
# 20          DHARAWAD                   P3
# 21             GADAG                   P3
# 22            HAVERI                   P3
# 23    UTTARA KANNADA                   P4
# 24           BALLARI                   P4
# 25             BIDAR                   P3
# 26        KALABURAGI                   P3
# 27           YADGIRI                   P4
# 28           RAICHUR                   P4
# 29            KOPPAL                   P3
