# %% [markdown]
# <a href="https://colab.research.google.com/github/Annie-blare/WSL_LAB/blob/main/TotalCerealsandMinorMillets_Production.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# Load the dataset
file_path = '/content/Agriculture_KAG_2016_17.csv'  # Update this with the correct path
data = pd.read_csv(file_path)

# Selecting the 'TotalNPK' and 'TotalCerealsandMinorMillets_Production' columns
X = data[['TotalNPK']]
y = data['TotalCerealsandMinorMillets_Production']

# Performing linear regression
model = LinearRegression()
model.fit(X, y)
m = model.coef_[0]  # Slope
c = model.intercept_  # Intercept

# Extracting 'TotalNPK' for Bengaluru
bengaluru_totalnpk = data.loc[data['District'] == 'BENGALURU', 'TotalNPK'].iloc[0]

# User provided perturbations in percentages
user_perturbations = [-20,-10,10,20]
# Converting percentages to fractions
perturbations_corrected = [p / 100.0 for p in user_perturbations]

# Calculating 'TotalCerealsandMinorMillets_Production(old)' for Bengaluru
cereals_production_old = data.loc[data['District'] == 'BENGALURU', 'TotalCerealsandMinorMillets_Production'].iloc[0]

# Min-max normalization for 'TotalCerealsandMinorMillets_Production(old)'
cereals_production_min = y.min()
cereals_production_max = y.max()
normalized_cereals_production_old = (cereals_production_old - cereals_production_min) / (cereals_production_max - cereals_production_min)

# Applying corrected perturbations and calculating new values
results_corrected = []
for p in perturbations_corrected:
    perturbed_totalnpk = bengaluru_totalnpk * (1 + p)
    cereals_production_new = m * perturbed_totalnpk + c
    normalized_cereals_production_new = (cereals_production_new - cereals_production_min) / (cereals_production_max - cereals_production_min)
    change_in_cereals_production = cereals_production_new - cereals_production_old
    impact = normalized_cereals_production_new - normalized_cereals_production_old

    results_corrected.append({
        'Perturbation': f'P{user_perturbations.index(p*100)+1}',
        'Magnitude (%)': p*100,
        'Cereals_Production(old)': cereals_production_old,
        'Normalized_Cereals_Production(old)': normalized_cereals_production_old,
        'Cereals_Production(new)': cereals_production_new,
        'Normalized_Cereals_Production(new)': normalized_cereals_production_new,
        'Change_in_Cereals_Production': change_in_cereals_production,
        'Impact': impact
    })

results_df_corrected = pd.DataFrame(results_corrected)
print(results_df_corrected)
# Out:
#   Perturbation  Magnitude (%)  Cereals_Production(old)  \
# 0           P1          -20.0                    69153
# 1           P2          -10.0                    69153
# 2           P3           10.0                    69153
# 3           P4           20.0                    69153
#
#    Normalized_Cereals_Production(old)  Cereals_Production(new)  \
# 0                            0.012664            174077.728952
# 1                            0.012664            187084.713490
# 2                            0.012664            213098.682566
# 3                            0.012664            226105.667105
#
#    Normalized_Cereals_Production(new)  Change_in_Cereals_Production    Impact
# 0                            0.110618                 104924.728952  0.097954
# 1                            0.122760                 117931.713490  0.110097
# 2                            0.147046                 143945.682566  0.134382
# 3                            0.159189                 156952.667105  0.146525

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# Load the dataset
file_path = '/content/Agriculture_KAG_2016_17.csv'  # Adjusted to the correct file path
data = pd.read_csv(file_path)

# Performing linear regression on the entire dataset
X = data[['TotalNPK']]
y = data['TotalCerealsandMinorMillets_Production']
model = LinearRegression()
model.fit(X, y)
m = model.coef_[0]  # Slope
c = model.intercept_  # Intercept

# User provided perturbations in percentages
user_perturbations = [-20,-10,10,20]
# Converting percentages to fractions for calculation
perturbations_corrected = [p / 100.0 for p in user_perturbations]

# Min-max normalization parameters for 'TotalCerealsandMinorMillets_Production'
cereals_production_min = y.min()
cereals_production_max = y.max()

# Loop through each unique district in the dataset
for district in data['District'].unique():
    # Extracting 'TotalNPK' and 'TotalCerealsandMinorMillets_Production' for the current district
    district_totalnpk = data.loc[data['District'] == district, 'TotalNPK'].iloc[0]
    cereals_production_old = data.loc[data['District'] == district, 'TotalCerealsandMinorMillets_Production'].iloc[0]
    normalized_cereals_production_old = (cereals_production_old - cereals_production_min) / (cereals_production_max - cereals_production_min)

    district_results = []

    # Applying perturbations and calculating new values for each perturbation
    for p in perturbations_corrected:
        perturbed_totalnpk = district_totalnpk * (1 + p)
        cereals_production_new = m * perturbed_totalnpk + c
        normalized_cereals_production_new = (cereals_production_new - cereals_production_min) / (cereals_production_max - cereals_production_min)
        change_in_cereals_production = cereals_production_new - cereals_production_old
        impact = normalized_cereals_production_new - normalized_cereals_production_old

        district_results.append({
            'Perturbation (%)': p * 100,
            'Cereals_Production(old)': cereals_production_old,
            'Normalized_Cereals_Production(old)': normalized_cereals_production_old,
            'Cereals_Production(new)': cereals_production_new,
            'Normalized_Cereals_Production(new)': normalized_cereals_production_new,
            'Change_in_Cereals_Production': change_in_cereals_production,
            'Impact': impact
        })

    # Convert the district results into a DataFrame and print it
    district_df = pd.DataFrame(district_results)
    print(f"Results for {district}:")
    print(district_df)
    print("\n")  # Add a newline for better readability between districts
# Out:
# Results for BENGALURU:
#    Perturbation (%)  Cereals_Production(old)  \
# 0             -20.0                    69153
# 1             -10.0                    69153
# 2              10.0                    69153
# 3              20.0                    69153
#
#    Normalized_Cereals_Production(old)  Cereals_Production(new)  \
# 0                            0.012664            174077.728952
# 1                            0.012664            187084.713490
# 2                            0.012664            213098.682566
# 3                            0.012664            226105.667105
#
#    Normalized_Cereals_Production(new)  Change_in_Cereals_Production    Impact
# 0                            0.110618                 104924.728952  0.097954
# 1                            0.122760                 117931.713490  0.110097
# 2                            0.147046                 143945.682566  0.134382
# 3                            0.159189                 156952.667105  0.146525
#
#
# Results for BENGALURU(R):
#    Perturbation (%)  Cereals_Production(old)  \
# 0             -20.0                   125232
# 1             -10.0                   125232
# 2              10.0                   125232
# 3              20.0                   125232
#
#    Normalized_Cereals_Production(old)  Cereals_Production(new)  \
# 0                            0.065017            155994.058642
# 1                            0.065017            166740.584392
# 2                            0.065017            188233.635891
# 3                            0.065017            198980.161640
#
#    Normalized_Cereals_Production(new)  Change_in_Cereals_Production    Impact
# 0                            0.093735                  30762.058642  0.028718
# 1                            0.103768                  41508.584392  0.038751
# 2                            0.123833                  63001.635891  0.058816
# 3                            0.133866                  73748.161640  0.068849
#
#
# Results for RAMANAGARA:
#    Perturbation (%)  Cereals_Production(old)  \
# 0             -20.0                   159008
# 1             -10.0                   159008
# 2              10.0                   159008
# 3              20.0                   159008
#
#    Normalized_Cereals_Production(old)  Cereals_Production(new)  \
# 0                            0.096549            103376.872283
# 1                            0.096549            107546.249738
# 2                            0.096549            115885.004647
# 3                            0.096549            120054.382102
#
#    Normalized_Cereals_Production(new)  Change_in_Cereals_Production    Impact
# 0                            0.044614                 -55631.127717 -0.051935
# 1                            0.048506                 -51461.750262 -0.048043
# 2                            0.056291                 -43122.995353 -0.040258
# 3                            0.060183                 -38953.617898 -0.036366
#
#
# Results for CHITRADURGA:
#    Perturbation (%)  Cereals_Production(old)  \
# 0             -20.0                   388849
# 1             -10.0                   388849
# 2              10.0                   388849
# 3              20.0                   388849
#
#    Normalized_Cereals_Production(old)  Cereals_Production(new)  \
# 0                             0.31112            230208.084536
# 1                             0.31112            250231.363523
# 2                             0.31112            290277.921495
# 3                             0.31112            310301.200482
#
#    Normalized_Cereals_Production(new)  Change_in_Cereals_Production    Impact
# 0                            0.163019                -158640.915464 -0.148101
# 1                            0.181712                -138617.636477 -0.129408
# 2                            0.219098                 -98571.078505 -0.092022
# 3                            0.237791                 -78547.799518 -0.073329
#
#
# Results for DAVANAGERE:
#    Perturbation (%)  Cereals_Production(old)  \
# 0             -20.0                  1126753
# 1             -10.0                  1126753
# 2              10.0                  1126753
# 3              20.0                  1126753
#
#    Normalized_Cereals_Production(old)  Cereals_Production(new)  \
# 0                                 1.0            514832.823845
# 1                                 1.0            570434.195245
# 2                                 1.0            681636.938045
# 3                                 1.0            737238.309445
#
#    Normalized_Cereals_Production(new)  Change_in_Cereals_Production    Impact
# 0                            0.428734                -611920.176155 -0.571266
# 1                            0.480641                -556318.804755 -0.519359
# 2                            0.584456                -445116.061955 -0.415544
# 3                            0.636364                -389514.690555 -0.363636
#
#
# Results for KOLAR:
#    Perturbation (%)  Cereals_Production(old)  \
# 0             -20.0                    69089
# 1             -10.0                    69089
# 2              10.0                    69089
# 3              20.0                    69089
#
#    Normalized_Cereals_Production(old)  Cereals_Production(new)  \
# 0                            0.012604            169078.047207
# 1                            0.012604            181460.071527
# 2                            0.012604            206224.120168
# 3                            0.012604            218606.144488
#
#    Normalized_Cereals_Production(new)  Change_in_Cereals_Production    Impact
# 0                            0.105950                  99989.047207  0.093346
# 1                            0.117510                 112371.071527  0.104905
# 2                            0.140628                 137135.120168  0.128024
# 3                            0.152188                 149517.144488  0.139584
#
#
# Results for CHIKKABALLAPURA:
#    Perturbation (%)  Cereals_Production(old)  \
# 0             -20.0                   165723
# 1             -10.0                   165723
# 2              10.0                   165723
# 3              20.0                   165723
#
#    Normalized_Cereals_Production(old)  Cereals_Production(new)  \
# 0                            0.102818            196607.544813
# 1                            0.102818            212430.756333
# 2                            0.102818            244077.179375
# 3                            0.102818            259900.390896
#
#    Normalized_Cereals_Production(new)  Change_in_Cereals_Production    Impact
# 0                            0.131651                  30884.544813  0.028833
# 1                            0.146423                  46707.756333  0.043605
# 2                            0.175967                  78354.179375  0.073149
# 3                            0.190738                  94177.390896  0.087921
#
#
# Results for SHIVAMOGGA:
#    Perturbation (%)  Cereals_Production(old)  \
# 0             -20.0                   613331
# 1             -10.0                   613331
# 2              10.0                   613331
# 3              20.0                   613331
#
#    Normalized_Cereals_Production(old)  Cereals_Production(new)  \
# 0                            0.520688            322724.516816
# 1                            0.520688            354312.349838
# 2                            0.520688            417488.015880
# 3                            0.520688            449075.848902
#
#    Normalized_Cereals_Production(new)  Change_in_Cereals_Production    Impact
# 0                            0.249389                -290606.483184 -0.271299
# 1                            0.278878                -259018.650162 -0.241810
# 2                            0.337856                -195842.984120 -0.182832
# 3                            0.367346                -164255.151098 -0.153343
#
#
# Results for TUMAKURU:
#    Perturbation (%)  Cereals_Production(old)  \
# 0             -20.0                   431562
# 1             -10.0                   431562
# 2              10.0                   431562
# 3              20.0                   431562
#
#    Normalized_Cereals_Production(old)  Cereals_Production(new)  \
# 0                            0.350995            240314.584062
# 1                            0.350995            261601.175490
# 2                            0.350995            304174.358344
# 3                            0.350995            325460.949771
#
#    Normalized_Cereals_Production(new)  Change_in_Cereals_Production    Impact
# 0                            0.172454                -191247.415938 -0.178542
# 1                            0.192326                -169960.824510 -0.158669
# 2                            0.232071                -127387.641656 -0.118924
# 3                            0.251943                -106101.050229 -0.099052
#
#
# Results for CHIKKAMAGALURU:
#    Perturbation (%)  Cereals_Production(old)  \
# 0             -20.0                   235695
# 1             -10.0                   235695
# 2              10.0                   235695
# 3              20.0                   235695
#
#    Normalized_Cereals_Production(old)  Cereals_Production(new)  \
# 0                            0.168141            372962.390345
# 1                            0.168141            410829.957557
# 2                            0.168141            486565.091982
# 3                            0.168141            524432.659195
#
#    Normalized_Cereals_Production(new)  Change_in_Cereals_Production    Impact
# 0                            0.296289                 137267.390345  0.128148
# 1                            0.331641                 175134.957557  0.163500
# 2                            0.402344                 250870.091982  0.234203
# 3                            0.437696                 288737.659195  0.269555
#
#
# Results for DAKSHINA KANNADA:
#    Perturbation (%)  Cereals_Production(old)  \
# 0             -20.0                   132588
# 1             -10.0                   132588
# 2              10.0                   132588
# 3              20.0                   132588
#
#    Normalized_Cereals_Production(old)  Cereals_Production(new)  \
# 0                            0.071884            152998.713597
# 1                            0.071884            163370.821216
# 2                            0.071884            184115.036454
# 3                            0.071884            194487.144073
#
#    Normalized_Cereals_Production(new)  Change_in_Cereals_Production    Impact
# 0                            0.090939                  20410.713597  0.019055
# 1                            0.100622                  30782.821216  0.028738
# 2                            0.119988                  51527.036454  0.048104
# 3                            0.129671                  61899.144073  0.057787
#
#
# Results for UDUPI:
#    Perturbation (%)  Cereals_Production(old)  \
# 0             -20.0                   138265
# 1             -10.0                   138265
# 2              10.0                   138265
# 3              20.0                   138265
#
#    Normalized_Cereals_Production(old)  Cereals_Production(new)  \
# 0                            0.077184             97466.534221
# 1                            0.077184            100897.119418
# 2                            0.077184            107758.289812
# 3                            0.077184            111188.875009
#
#    Normalized_Cereals_Production(new)  Change_in_Cereals_Production    Impact
# 0                            0.039096                 -40798.465779 -0.038088
# 1                            0.042299                 -37367.880582 -0.034885
# 2                            0.048704                 -30506.710188 -0.028480
# 3                            0.051907                 -27076.124991 -0.025277
#
#
# Results for HASSAN:
#    Perturbation (%)  Cereals_Production(old)  \
# 0             -20.0                   634691
# 1             -10.0                   634691
# 2              10.0                   634691
# 3              20.0                   634691
#
#    Normalized_Cereals_Production(old)  Cereals_Production(new)  \
# 0                            0.540629            375497.943230
# 1                            0.540629            413682.454553
# 2                            0.540629            490051.477199
# 3                            0.540629            528235.988522
#
#    Normalized_Cereals_Production(new)  Change_in_Cereals_Production    Impact
# 0                            0.298656                -259193.056770 -0.241973
# 1                            0.334304                -221008.545447 -0.206325
# 2                            0.405599                -144639.522801 -0.135030
# 3                            0.441247                -106455.011478 -0.099382
#
#
# Results for KODAGU:
#    Perturbation (%)  Cereals_Production(old)  \
# 0             -20.0                   104224
# 1             -10.0                   104224
# 2              10.0                   104224
# 3              20.0                   104224
#
#    Normalized_Cereals_Production(old)  Cereals_Production(new)  \
# 0                            0.045405            252809.324422
# 1                            0.045405            275657.758394
# 2                            0.045405            321354.626338
# 3                            0.045405            344203.060310
#
#    Normalized_Cereals_Production(new)  Change_in_Cereals_Production    Impact
# 0                            0.184119                 148585.324422  0.138714
# 1                            0.205449                 171433.758394  0.160044
# 2                            0.248110                 217130.626338  0.202705
# 3                            0.269440                 239979.060310  0.224036
#
#
# Results for MANDYA:
#    Perturbation (%)  Cereals_Production(old)  \
# 0             -20.0                   367794
# 1             -10.0                   367794
# 2              10.0                   367794
# 3              20.0                   367794
#
#    Normalized_Cereals_Production(old)  Cereals_Production(new)  \
# 0                            0.291464            340352.858967
# 1                            0.291464            374144.234757
# 2                            0.291464            441726.986338
# 3                            0.291464            475518.362128
#
#    Normalized_Cereals_Production(new)  Change_in_Cereals_Production    Impact
# 0                            0.265846                 -27441.141033 -0.025618
# 1                            0.297392                   6350.234757  0.005928
# 2                            0.360485                  73932.986338  0.069021
# 3                            0.392031                 107724.362128  0.100567
#
#
# Results for MYSURU:
#    Perturbation (%)  Cereals_Production(old)  \
# 0             -20.0                   582518
# 1             -10.0                   582518
# 2              10.0                   582518
# 3              20.0                   582518
#
#    Normalized_Cereals_Production(old)  Cereals_Production(new)  \
# 0                            0.491922            346852.445235
# 1                            0.491922            381456.269309
# 2                            0.491922            450663.917456
# 3                            0.491922            485267.741530
#
#    Normalized_Cereals_Production(new)  Change_in_Cereals_Production    Impact
# 0                            0.271914                -235665.554765 -0.220009
# 1                            0.304219                -201061.730691 -0.187704
# 2                            0.368828                -131854.082544 -0.123094
# 3                            0.401133                 -97250.258470 -0.090789
#
#
# Results for CHAMARAJANAGAR:
#    Perturbation (%)  Cereals_Production(old)  \
# 0             -20.0                   226134
# 1             -10.0                   226134
# 2              10.0                   226134
# 3              20.0                   226134
#
#    Normalized_Cereals_Production(old)  Cereals_Production(new)  \
# 0                            0.159215            176278.481719
# 1                            0.159215            189560.560354
# 2                            0.159215            216124.717622
# 3                            0.159215            229406.796257
#
#    Normalized_Cereals_Production(new)  Change_in_Cereals_Production    Impact
# 0                            0.112672                 -49855.518281 -0.046543
# 1                            0.125072                 -36573.439646 -0.034144
# 2                            0.149871                 -10009.282378 -0.009344
# 3                            0.162271                   3272.796257  0.003055
#
#
# Results for BELAGAVI:
#    Perturbation (%)  Cereals_Production(old)  \
# 0             -20.0                   972447
# 1             -10.0                   972447
# 2              10.0                   972447
# 3              20.0                   972447
#
#    Normalized_Cereals_Production(old)  Cereals_Production(new)  \
# 0                            0.855946             8.735064e+05
# 1                            0.855946             9.739420e+05
# 2                            0.855946             1.174813e+06
# 3                            0.855946             1.275249e+06
#
#    Normalized_Cereals_Production(new)  Change_in_Cereals_Production    Impact
# 0                            0.763578                 -98940.579009 -0.092367
# 1                            0.857341                   1494.992034  0.001396
# 2                            1.044867                 202366.134121  0.188922
# 3                            1.138630                 302801.705164  0.282684
#
#
# Results for VIJAYAPURA:
#    Perturbation (%)  Cereals_Production(old)  \
# 0             -20.0                   453546
# 1             -10.0                   453546
# 2              10.0                   453546
# 3              20.0                   453546
#
#    Normalized_Cereals_Production(old)  Cereals_Production(new)  \
# 0                            0.371519            312095.729108
# 1                            0.371519            342354.963666
# 2                            0.371519            402873.432781
# 3                            0.371519            433132.667339
#
#    Normalized_Cereals_Production(new)  Change_in_Cereals_Production    Impact
# 0                            0.239466                -141450.270892 -0.132053
# 1                            0.267715                -111191.036334 -0.103804
# 2                            0.324213                 -50672.567219 -0.047306
# 3                            0.352462                 -20413.332661 -0.019057
#
#
# Results for BAGALKOT:
#    Perturbation (%)  Cereals_Production(old)  \
# 0             -20.0                   410788
# 1             -10.0                   410788
# 2              10.0                   410788
# 3              20.0                   410788
#
#    Normalized_Cereals_Production(old)  Cereals_Production(new)  \
# 0                            0.331602            448622.752744
# 1                            0.331602            495947.865256
# 2                            0.331602            590598.090281
# 3                            0.331602            637923.202793
#
#    Normalized_Cereals_Production(new)  Change_in_Cereals_Production    Impact
# 0                            0.366923                  37834.752744  0.035321
# 1                            0.411104                  85159.865256  0.079502
# 2                            0.499466                 179810.090281  0.167864
# 3                            0.543647                 227135.202793  0.212045
#
#
# Results for DHARAWAD:
#    Perturbation (%)  Cereals_Production(old)  \
# 0             -20.0                   199594
# 1             -10.0                   199594
# 2              10.0                   199594
# 3              20.0                   199594
#
#    Normalized_Cereals_Production(old)  Cereals_Production(new)  \
# 0                            0.134439            236890.694868
# 1                            0.134439            257749.300146
# 2                            0.134439            299466.510701
# 3                            0.134439            320325.115979
#
#    Normalized_Cereals_Production(new)  Change_in_Cereals_Production    Impact
# 0                            0.169257                  37296.694868  0.034819
# 1                            0.188730                  58155.300146  0.054292
# 2                            0.227676                  99872.510701  0.093237
# 3                            0.247149                 120731.115979  0.112710
#
#
# Results for GADAG:
#    Perturbation (%)  Cereals_Production(old)  \
# 0             -20.0                   227348
# 1             -10.0                   227348
# 2              10.0                   227348
# 3              20.0                   227348
#
#    Normalized_Cereals_Production(old)  Cereals_Production(new)  \
# 0                            0.160349            173943.808905
# 1                            0.160349            186934.053437
# 2                            0.160349            212914.542502
# 3                            0.160349            225904.787035
#
#    Normalized_Cereals_Production(new)  Change_in_Cereals_Production    Impact
# 0                            0.110493                 -53404.191095 -0.049856
# 1                            0.122620                 -40413.946563 -0.037729
# 2                            0.146874                 -14433.457498 -0.013475
# 3                            0.159001                  -1443.212965 -0.001347
#
#
# Results for HAVERI:
#    Perturbation (%)  Cereals_Production(old)  \
# 0             -20.0                   577674
# 1             -10.0                   577674
# 2              10.0                   577674
# 3              20.0                   577674
#
#    Normalized_Cereals_Production(old)  Cereals_Production(new)  \
# 0                              0.4874            360186.417887
# 1                              0.4874            396456.988542
# 2                              0.4874            468998.129853
# 3                              0.4874            505268.700508
#
#    Normalized_Cereals_Production(new)  Change_in_Cereals_Production    Impact
# 0                            0.284362                -217487.582113 -0.203038
# 1                            0.318223                -181217.011458 -0.169177
# 2                            0.385944                -108675.870147 -0.101456
# 3                            0.419805                 -72405.299492 -0.067595
#
#
# Results for UTTARA KANNADA:
#    Perturbation (%)  Cereals_Production(old)  \
# 0             -20.0                   177080
# 1             -10.0                   177080
# 2              10.0                   177080
# 3              20.0                   177080
#
#    Normalized_Cereals_Production(old)  Cereals_Production(new)  \
# 0                             0.11342            138392.500501
# 1                             0.11342            146938.831482
# 2                             0.11342            164031.493446
# 3                             0.11342            172577.824428
#
#    Normalized_Cereals_Production(new)  Change_in_Cereals_Production    Impact
# 0                            0.077303                 -38687.499499 -0.036117
# 1                            0.085282                 -30141.168518 -0.028139
# 2                            0.101239                 -13048.506554 -0.012182
# 3                            0.109217                  -4502.175572 -0.004203
#
#
# Results for BALLARI:
#    Perturbation (%)  Cereals_Production(old)  \
# 0             -20.0                   703457
# 1             -10.0                   703457
# 2              10.0                   703457
# 3              20.0                   703457
#
#    Normalized_Cereals_Production(old)  Cereals_Production(new)  \
# 0                            0.604827            620562.700736
# 1                            0.604827            689380.306747
# 2                            0.604827            827015.518770
# 3                            0.604827            895833.124781
#
#    Normalized_Cereals_Production(new)  Change_in_Cereals_Production    Impact
# 0                            0.527439                 -82894.299264 -0.077387
# 1                            0.591685                 -14076.693253 -0.013141
# 2                            0.720176                 123558.518770  0.115350
# 3                            0.784422                 192376.124781  0.179595
#
#
# Results for BIDAR:
#    Perturbation (%)  Cereals_Production(old)  \
# 0             -20.0                    55588
# 1             -10.0                    55588
# 2              10.0                    55588
# 3              20.0                    55588
#
#    Normalized_Cereals_Production(old)  Cereals_Production(new)  \
# 0                                 0.0            180095.203051
# 1                                 0.0            193854.371852
# 2                                 0.0            221372.709453
# 3                                 0.0            235131.878254
#
#    Normalized_Cereals_Production(new)  Change_in_Cereals_Production    Impact
# 0                            0.116235                 124507.203051  0.116235
# 1                            0.129080                 138266.371852  0.129080
# 2                            0.154770                 165784.709453  0.154770
# 3                            0.167616                 179543.878254  0.167616
#
#
# Results for KALABURAGI:
#    Perturbation (%)  Cereals_Production(old)  \
# 0             -20.0                   331500
# 1             -10.0                   331500
# 2              10.0                   331500
# 3              20.0                   331500
#
#    Normalized_Cereals_Production(old)  Cereals_Production(new)  \
# 0                            0.257581            311073.472751
# 1                            0.257581            341204.925264
# 2                            0.257581            401467.830291
# 3                            0.257581            431599.282804
#
#    Normalized_Cereals_Production(new)  Change_in_Cereals_Production    Impact
# 0                            0.238512                 -20426.527249 -0.019069
# 1                            0.266641                   9704.925264  0.009060
# 2                            0.322901                  69967.830291  0.065319
# 3                            0.351030                 100099.282804  0.093449
#
#
# Results for YADGIRI:
#    Perturbation (%)  Cereals_Production(old)  \
# 0             -20.0                   291376
# 1             -10.0                   291376
# 2              10.0                   291376
# 3              20.0                   291376
#
#    Normalized_Cereals_Production(old)  Cereals_Production(new)  \
# 0                            0.220123            477982.490988
# 1                            0.220123            528977.570781
# 2                            0.220123            630967.730366
# 3                            0.220123            681962.810159
#
#    Normalized_Cereals_Production(new)  Change_in_Cereals_Production    Impact
# 0                            0.394332                 186606.490988  0.174209
# 1                            0.441939                 237601.570781  0.221816
# 2                            0.537153                 339591.730366  0.317030
# 3                            0.584760                 390586.810159  0.364637
#
#
# Results for RAICHUR:
#    Perturbation (%)  Cereals_Production(old)  \
# 0             -20.0                   622361
# 1             -10.0                   622361
# 2              10.0                   622361
# 3              20.0                   622361
#
#    Normalized_Cereals_Production(old)  Cereals_Production(new)  \
# 0                            0.529118            593359.075244
# 1                            0.529118            658776.228069
# 2                            0.529118            789610.533719
# 3                            0.529118            855027.686544
#
#    Normalized_Cereals_Production(new)  Change_in_Cereals_Production    Impact
# 0                            0.502043                 -29001.924756 -0.027075
# 1                            0.563114                  36415.228069  0.033996
# 2                            0.685256                 167249.533719  0.156138
# 3                            0.746327                 232666.686544  0.217209
#
#
# Results for KOPPAL:
#    Perturbation (%)  Cereals_Production(old)  \
# 0             -20.0                   565846
# 1             -10.0                   565846
# 2              10.0                   565846
# 3              20.0                   565846
#
#    Normalized_Cereals_Production(old)  Cereals_Production(new)  \
# 0                            0.476358            398358.095206
# 1                            0.476358            439400.125526
# 2                            0.476358            521484.186166
# 3                            0.476358            562526.216486
#
#    Normalized_Cereals_Production(new)  Change_in_Cereals_Production    Impact
# 0                            0.319997                -167487.904794 -0.156361
# 1                            0.358313                -126445.874474 -0.118045
# 2                            0.434943                 -44361.813834 -0.041415
# 3                            0.473259                  -3319.783514 -0.003099

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np

# Load the dataset
file_path = '/content/Agriculture_KAG_2016_17.csv'  # Adjust this path as needed
data = pd.read_csv(file_path)

# Performing linear regression on the entire dataset
X = data[['TotalNPK']]
y = data['TotalCerealsandMinorMillets_Production']
model = LinearRegression()
model.fit(X, y)
m = model.coef_[0]  # Slope
c = model.intercept_  # Intercept

# User provided perturbations in percentages
user_perturbations = [-20,-10,10,20]
# Converting percentages to fractions for calculation
perturbations_corrected = [p / 100.0 for p in user_perturbations]

# Min-max normalization parameters for 'Rice_Production'
rice_production_min = y.min()
rice_production_max = y.max()

# Loop through each unique district in the dataset
for district in data['District'].unique():
    district_totalnpk = data.loc[data['District'] == district, 'TotalNPK'].iloc[0]
    rice_production_old = data.loc[data['District'] == district, 'TotalCerealsandMinorMillets_Production'].iloc[0]
    normalized_old = (rice_production_old - rice_production_min) / (rice_production_max - rice_production_min)

    impacts = []

    for p in perturbations_corrected:
        perturbed_totalnpk = district_totalnpk * (1 + p)
        rice_production_new = m * perturbed_totalnpk + c
        normalized_new = (rice_production_new - rice_production_min) / (rice_production_max - rice_production_min)
        impact = (normalized_new - normalized_old) * 100  # Impact calculation
        impacts.append(impact)

    # Function to generate colors based on impact
    def generate_colors(impacts):
        # Separate positive and negative impacts
        positive_impacts = [imp for imp in impacts if imp > 0]
        negative_impacts = [imp for imp in impacts if imp < 0]

        # Calculate gradients
        # For positive impacts: Dark to light green (we will reverse this to meet your requirement)
        green_gradients = np.linspace(1, 0.5, len(positive_impacts)) if positive_impacts else []
        # For negative impacts: Light to dark red
        red_gradients = np.linspace(0.5, 1, len(negative_impacts)) if negative_impacts else []

        # Assign colors based on impact value, with a transition from dark to light for positive impacts
        colors = []
        for impact in impacts:
            if impact > 0:
                # Find the index of the impact in positive_impacts to get the corresponding shade
                index = positive_impacts.index(impact)
                color = (0, green_gradients[index], 0)  # Green shade from dark to light
            elif impact < 0:
                # Find the index of the impact in negative_impacts to get the corresponding shade
                index = negative_impacts.index(impact)
                color = (red_gradients[index], 0, 0)  # Red shade from light to dark
            else:
                color = (0.8, 0.8, 0.8)  # Grey for neutral impact
            colors.append(color)

        return colors

    # Generate colors based on sorted impacts
    colors = generate_colors(impacts)

    # Plotting the impacts of each perturbation with custom colors
    plt.figure(figsize=(10, 6))
    plt.bar([f'{p*100:+.0f}%' for p in perturbations_corrected], impacts, color=colors)
    plt.xlabel('Perturbation (Magnitude in %)')
    plt.ylabel('Impact')
    plt.title(f'Impact of Perturbations on TotalCerealsandMinorMillets_Production for {district}')
    plt.axhline(0, color='gray', linewidth=0.8)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# %%
######SIMILAR LINE GRAPH ANAYSIS
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np

# Load the dataset
file_path = '/content/Agriculture_KAG_2016_17.csv'  # Adjust this path as needed
data = pd.read_csv(file_path)

# Performing linear regression on the entire dataset
X = data[['TotalNPK']]
y = data['TotalCerealsandMinorMillets_Production']
model = LinearRegression()
model.fit(X, y)
m = model.coef_[0]  # Slope
c = model.intercept_  # Intercept

# User provided perturbations in percentages
user_perturbations = [-20, -10, 10, 20]
# Converting percentages to fractions for calculation
perturbations_corrected = [p / 100.0 for p in user_perturbations]

# Min-max normalization parameters for 'Rice_Production'
rice_production_min = y.min()
rice_production_max = y.max()

# Function to generate colors based on impact
def generate_colors(impacts):
    # Reverse the lists to intensify the color with the impact
    positive_impacts = sorted([imp for imp in impacts if imp > 0], reverse=True)
    negative_impacts = sorted([imp for imp in impacts if imp < 0], reverse=False)  # Reverse sorting for negative

    # Calculate gradients
    green_gradients = np.linspace(0.5, 1, len(positive_impacts)) if positive_impacts else []
    red_gradients = np.linspace(0.5, 1, len(negative_impacts)) if negative_impacts else []

    colors = []
    for impact in impacts:
        if impact > 0:
            index = positive_impacts.index(impact)
            color = (0, green_gradients[index], 0)  # More intense green for higher positive impacts
        elif impact < 0:
            index = negative_impacts.index(impact)
            color = (red_gradients[index], 0, 0)  # More intense red for more negative impacts
        else:
            color = (0.8, 0.8, 0.8)  # Neutral grey for no impact
        colors.append(color)

    return colors

# Loop through each unique district in the dataset
for district in data['District'].unique():
    district_totalnpk = data.loc[data['District'] == district, 'TotalNPK'].iloc[0]
    rice_production_old = data.loc[data['District'] == district, 'TotalCerealsandMinorMillets_Production'].iloc[0]
    normalized_old = (rice_production_old - rice_production_min) / (rice_production_max - rice_production_min)

    impacts = []

    for p in perturbations_corrected:
        perturbed_totalnpk = district_totalnpk * (1 + p)
        rice_production_new = m * perturbed_totalnpk + c
        normalized_new = (rice_production_new - rice_production_min) / (rice_production_max - rice_production_min)
        impact = (normalized_new - normalized_old) * 100  # Impact calculation
        impacts.append(impact)

    # Generate colors based on sorted impacts
    colors = generate_colors(impacts)

    # Plotting the impacts of each perturbation with a line graph
    plt.figure(figsize=(10, 6))
    for i, (perturbation, impact) in enumerate(zip(perturbations_corrected, impacts)):
        plt.plot(perturbation*100, impact, 'o', color=colors[i], label=f'{perturbation*100:+.0f}%: {impact:.2f}%')

    # Adding a table with key-value pairs at the corner
    table_text = '\n'.join([f'{p:+}%: {impact:.2f}%' for p, impact in zip(perturbations_corrected, impacts)])
    plt.text(0.02, 0.02, table_text, transform=plt.gca().transAxes, fontsize=8, verticalalignment='bottom', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))

    # Connect dots with a line
    plt.plot([p*100 for p in perturbations_corrected], impacts, 'k-')

    plt.xlabel('Perturbation (Magnitude in %)')
    plt.ylabel('Impact (%)')
    plt.title(f'Impact of Perturbations on Rice Production for {district}')
    plt.axhline(0, color='gray', linewidth=0.8)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.legend()
    plt.show()

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# Load the dataset
file_path = '/content/Agriculture_KAG_2016_17.csv'  # Adjust this path as needed
data = pd.read_csv(file_path)

# Performing linear regression on the entire dataset
X = data[['TotalNPK']]
y = data['TotalCerealsandMinorMillets_Production']
model = LinearRegression()
model.fit(X, y)
m = model.coef_[0]  # Slope
c = model.intercept_  # Intercept

# User provided perturbations in percentages
user_perturbations = [-20,-10,10,20]
# Converting percentages to fractions for calculation
perturbations_corrected = [p / 100.0 for p in user_perturbations]

# Min-max normalization parameters for 'Rice_Production'
rice_production_min = y.min()
rice_production_max = y.max()

# Initialize an empty list to store results for each district
district_results = []

# Loop through each unique district in the dataset
for district in data['District'].unique():
    district_totalnpk = data.loc[data['District'] == district, 'TotalNPK'].iloc[0]
    rice_production_old = data.loc[data['District'] == district, 'TotalCerealsandMinorMillets_Production'].iloc[0]
    normalized_old = (rice_production_old - rice_production_min) / (rice_production_max - rice_production_min)

    positive_impacts = []
    negative_impacts = []

    for p in perturbations_corrected:
        perturbed_totalnpk = district_totalnpk * (1 + p)
        rice_production_new = m * perturbed_totalnpk + c
        normalized_new = (rice_production_new - rice_production_min) / (rice_production_max - rice_production_min)
        impact = (normalized_new - normalized_old) * 100  # Impact calculation

        if impact > 0:
            positive_impacts.append((impact, p))
        elif impact < 0:
            negative_impacts.append((impact, p))

    # Choose perturbation based on conditions
    if positive_impacts and not negative_impacts:
        chosen_perturbation = max(positive_impacts)[1]
    elif not positive_impacts and negative_impacts:
        chosen_perturbation = max(negative_impacts)[1]       ####absolute differece between new and old is less=max negative value
    elif positive_impacts and negative_impacts:
        chosen_perturbation = max(positive_impacts)[1]

    district_results.append({
        'District': district,
        'Perturbation_Choosen': f'P{user_perturbations.index(chosen_perturbation*100)+1}'
    })

# Convert the results into a DataFrame and display
results_df = pd.DataFrame(district_results)
print(results_df)

# Convert the results into a DataFrame and display
results_df = pd.DataFrame(district_results)
print(results_df)
# Out:
#             District Perturbation_Choosen
# 0          BENGALURU                   P4
# 1       BENGALURU(R)                   P4
# 2         RAMANAGARA                   P4
# 3        CHITRADURGA                   P4
# 4         DAVANAGERE                   P4
# 5              KOLAR                   P4
# 6    CHIKKABALLAPURA                   P4
# 7         SHIVAMOGGA                   P4
# 8           TUMAKURU                   P4
# 9     CHIKKAMAGALURU                   P4
# 10  DAKSHINA KANNADA                   P4
# 11             UDUPI                   P4
# 12            HASSAN                   P4
# 13            KODAGU                   P4
# 14            MANDYA                   P4
# 15            MYSURU                   P4
# 16    CHAMARAJANAGAR                   P4
# 17          BELAGAVI                   P4
# 18        VIJAYAPURA                   P4
# 19          BAGALKOT                   P4
# 20          DHARAWAD                   P4
# 21             GADAG                   P4
# 22            HAVERI                   P4
# 23    UTTARA KANNADA                   P4
# 24           BALLARI                   P4
# 25             BIDAR                   P4
# 26        KALABURAGI                   P4
# 27           YADGIRI                   P4
# 28           RAICHUR                   P4
# 29            KOPPAL                   P4
#             District Perturbation_Choosen
# 0          BENGALURU                   P4
# 1       BENGALURU(R)                   P4
# 2         RAMANAGARA                   P4
# 3        CHITRADURGA                   P4
# 4         DAVANAGERE                   P4
# 5              KOLAR                   P4
# 6    CHIKKABALLAPURA                   P4
# 7         SHIVAMOGGA                   P4
# 8           TUMAKURU                   P4
# 9     CHIKKAMAGALURU                   P4
# 10  DAKSHINA KANNADA                   P4
# 11             UDUPI                   P4
# 12            HASSAN                   P4
# 13            KODAGU                   P4
# 14            MANDYA                   P4
# 15            MYSURU                   P4
# 16    CHAMARAJANAGAR                   P4
# 17          BELAGAVI                   P4
# 18        VIJAYAPURA                   P4
# 19          BAGALKOT                   P4
# 20          DHARAWAD                   P4
# 21             GADAG                   P4
# 22            HAVERI                   P4
# 23    UTTARA KANNADA                   P4
# 24           BALLARI                   P4
# 25             BIDAR                   P4
# 26        KALABURAGI                   P4
# 27           YADGIRI                   P4
# 28           RAICHUR                   P4
# 29            KOPPAL                   P4

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Load the dataset
file_path = '/content/Agriculture_KAG_2016_17.csv'  # Adjust this path as needed
data = pd.read_csv(file_path)

# Performing linear regression on the entire dataset
X = data[['TotalNPK']]
y = data['TotalCerealsandMinorMillets_Production']
model = LinearRegression()
model.fit(X, y)
m = model.coef_[0]  # Slope
c = model.intercept_  # Intercept

# User provided perturbations in percentages
user_perturbations = [-20, -10, 10, 20]
# Converting percentages to fractions for calculation
perturbations_corrected = [p / 100.0 for p in user_perturbations]

# Calculate impacts for each district and perturbation
impact_results = []

for district in data['District'].unique():
    district_data = []
    district_totalnpk = data.loc[data['District'] == district, 'TotalNPK'].iloc[0]
    original_rice_production = data.loc[data['District'] == district, 'TotalCerealsandMinorMillets_Production'].iloc[0]
    for perturbation in perturbations_corrected:
        perturbed_totalnpk = district_totalnpk * (1 + perturbation)
        rice_production_predicted = m * perturbed_totalnpk + c
        normalized_new = (rice_production_predicted - y.min()) / (y.max() - y.min())
        normalized_old = (original_rice_production - y.min()) / (y.max() - y.min())
        impact = (normalized_new - normalized_old) * 100
        district_data.append(impact)
    impact_results.append(district_data)

# Create a DataFrame for the heatmap
impact_df = pd.DataFrame(impact_results, columns=[f'P{i+1}' for i in range(len(user_perturbations))], index=data['District'].unique())

# Custom color palette from red to green
cmap = sns.diverging_palette(10, 133, s=99, l=55, sep=3, as_cmap=True)

# Plotting the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(impact_df, cmap=cmap, annot=True, cbar_kws={'label': 'Impact (%)'})
plt.title('Percentage Change in TotalCerealsandMinorMillets_Production Due to Perturbations')
plt.ylabel('District')
plt.xlabel('Perturbation')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
